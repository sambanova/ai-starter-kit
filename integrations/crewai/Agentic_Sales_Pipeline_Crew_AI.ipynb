# %% [markdown]
# ## Agentic Sales Pipeline SambaNova & CrewAI

# %% [markdown]
# ## Initial Imports

# %% [markdown]
# Get your Sambanova API Key Here https://cloud.sambanova.ai/
#
#
# Get your Serper API Key Here https://serper.dev/

# %%
# Install Requirements

# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: crewai in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from -r requirements.txt (line 1)) (0.76.9)
# Requirement already satisfied: crewai_tools in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from -r requirements.txt (line 2)) (0.13.4)
# Requirement already satisfied: langchain_community in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from -r requirements.txt (line 3)) (0.3.5)
# Requirement already satisfied: python-dotenv in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from -r requirements.txt (line 4)) (1.0.1)
# Requirement already satisfied: appdirs>=1.4.4 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from crewai->-r requirements.txt (line 1)) (1.4.4)
# Requirement already satisfied: auth0-python>=4.7.1 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from crewai->-r requirements.txt (line 1)) (4.7.2)
# Requirement already satisfied: chromadb>=0.4.24 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from crewai->-r requirements.txt (line 1)) (0.4.24)
# Requirement already satisfied: click>=8.1.7 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from crewai->-r requirements.txt (line 1)) (8.1.7)
# Requirement already satisfied: instructor>=1.3.3 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from crewai->-r requirements.txt (line 1)) (1.6.3)
# Requirement already satisfied: json-repair>=0.25.2 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from crewai->-r requirements.txt (line 1)) (0.30.0)
# Requirement already satisfied: jsonref>=1.1.0 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from crewai->-r requirements.txt (line 1)) (1.1.0)
# Requirement already satisfied: langchain>=0.2.16 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from crewai->-r requirements.txt (line 1)) (0.3.7)
# Requirement already satisfied: litellm>=1.44.22 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from crewai->-r requirements.txt (line 1)) (1.53.1)
# Requirement already satisfied: openai>=1.13.3 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from crewai->-r requirements.txt (line 1)) (1.55.3)
# Requirement already satisfied: opentelemetry-api>=1.22.0 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from crewai->-r requirements.txt (line 1)) (1.27.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http>=1.22.0 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from crewai->-r requirements.txt (line 1)) (1.27.0)
# Requirement already satisfied: opentelemetry-sdk>=1.22.0 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from crewai->-r requirements.txt (line 1)) (1.27.0)
# Requirement already satisfied: pydantic>=2.4.2 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from crewai->-r requirements.txt (line 1)) (2.9.2)
# Requirement already satisfied: pyvis>=0.3.2 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from crewai->-r requirements.txt (line 1)) (0.3.2)
# Requirement already satisfied: regex>=2024.9.11 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from crewai->-r requirements.txt (line 1)) (2024.9.11)
# Requirement already satisfied: tomli-w>=1.1.0 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from crewai->-r requirements.txt (line 1)) (1.1.0)
# Requirement already satisfied: tomli>=2.0.2 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from crewai->-r requirements.txt (line 1)) (2.0.2)
# Requirement already satisfied: uv>=0.4.25 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from crewai->-r requirements.txt (line 1)) (0.4.29)
# Requirement already satisfied: beautifulsoup4>=4.12.3 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from crewai_tools->-r requirements.txt (line 2)) (4.12.3)
# Requirement already satisfied: docker>=7.1.0 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from crewai_tools->-r requirements.txt (line 2)) (7.1.0)
# Requirement already satisfied: docx2txt>=0.8 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from crewai_tools->-r requirements.txt (line 2)) (0.8)
# Requirement already satisfied: embedchain>=0.1.114 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from crewai_tools->-r requirements.txt (line 2)) (0.1.124)
# Requirement already satisfied: lancedb>=0.5.4 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from crewai_tools->-r requirements.txt (line 2)) (0.15.0)
# Requirement already satisfied: pyright>=1.1.350 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from crewai_tools->-r requirements.txt (line 2)) (1.1.387)
# Requirement already satisfied: pytest>=8.0.0 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from crewai_tools->-r requirements.txt (line 2)) (8.3.3)
# Requirement already satisfied: pytube>=15.0.0 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from crewai_tools->-r requirements.txt (line 2)) (15.0.0)
# Requirement already satisfied: requests>=2.31.0 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from crewai_tools->-r requirements.txt (line 2)) (2.32.3)
# Requirement already satisfied: selenium>=4.18.1 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from crewai_tools->-r requirements.txt (line 2)) (4.26.1)
# Requirement already satisfied: PyYAML>=5.3 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from langchain_community->-r requirements.txt (line 3)) (6.0.2)
# Requirement already satisfied: SQLAlchemy<2.0.36,>=1.4 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from langchain_community->-r requirements.txt (line 3)) (2.0.35)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from langchain_community->-r requirements.txt (line 3)) (3.10.10)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from langchain_community->-r requirements.txt (line 3)) (0.6.7)
# Requirement already satisfied: httpx-sse<0.5.0,>=0.4.0 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from langchain_community->-r requirements.txt (line 3)) (0.4.0)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.15 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from langchain_community->-r requirements.txt (line 3)) (0.3.15)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.125 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from langchain_community->-r requirements.txt (line 3)) (0.1.139)
# Requirement already satisfied: numpy<2,>=1 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from langchain_community->-r requirements.txt (line 3)) (1.26.4)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from langchain_community->-r requirements.txt (line 3)) (2.6.1)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from langchain_community->-r requirements.txt (line 3)) (9.0.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community->-r requirements.txt (line 3)) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community->-r requirements.txt (line 3)) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community->-r requirements.txt (line 3)) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community->-r requirements.txt (line 3)) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community->-r requirements.txt (line 3)) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community->-r requirements.txt (line 3)) (1.17.1)
# Requirement already satisfied: cryptography<44.0.0,>=43.0.1 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from auth0-python>=4.7.1->crewai->-r requirements.txt (line 1)) (43.0.3)
# Requirement already satisfied: pyjwt<3.0.0,>=2.8.0 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from auth0-python>=4.7.1->crewai->-r requirements.txt (line 1)) (2.9.0)
# Requirement already satisfied: urllib3<3.0.0,>=2.0.7 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from auth0-python>=4.7.1->crewai->-r requirements.txt (line 1)) (2.2.3)
# Requirement already satisfied: soupsieve>1.2 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from beautifulsoup4>=4.12.3->crewai_tools->-r requirements.txt (line 2)) (2.6)
# Requirement already satisfied: build>=1.0.3 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from chromadb>=0.4.24->crewai->-r requirements.txt (line 1)) (1.2.2.post1)
# Requirement already satisfied: chroma-hnswlib==0.7.3 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from chromadb>=0.4.24->crewai->-r requirements.txt (line 1)) (0.7.3)
# Requirement already satisfied: fastapi>=0.95.2 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from chromadb>=0.4.24->crewai->-r requirements.txt (line 1)) (0.115.4)
# Requirement already satisfied: uvicorn>=0.18.3 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.4.24->crewai->-r requirements.txt (line 1)) (0.32.0)
# Requirement already satisfied: posthog>=2.4.0 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from chromadb>=0.4.24->crewai->-r requirements.txt (line 1)) (3.7.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from chromadb>=0.4.24->crewai->-r requirements.txt (line 1)) (4.12.2)
# Requirement already satisfied: pulsar-client>=3.1.0 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from chromadb>=0.4.24->crewai->-r requirements.txt (line 1)) (3.5.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from chromadb>=0.4.24->crewai->-r requirements.txt (line 1)) (1.20.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from chromadb>=0.4.24->crewai->-r requirements.txt (line 1)) (1.27.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from chromadb>=0.4.24->crewai->-r requirements.txt (line 1)) (0.48b0)
# Requirement already satisfied: tokenizers>=0.13.2 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from chromadb>=0.4.24->crewai->-r requirements.txt (line 1)) (0.20.1)
# Requirement already satisfied: pypika>=0.48.9 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from chromadb>=0.4.24->crewai->-r requirements.txt (line 1)) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from chromadb>=0.4.24->crewai->-r requirements.txt (line 1)) (4.66.6)
# Requirement already satisfied: overrides>=7.3.1 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from chromadb>=0.4.24->crewai->-r requirements.txt (line 1)) (7.7.0)
# Requirement already satisfied: importlib-resources in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from chromadb>=0.4.24->crewai->-r requirements.txt (line 1)) (6.4.5)
# Requirement already satisfied: grpcio>=1.58.0 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from chromadb>=0.4.24->crewai->-r requirements.txt (line 1)) (1.67.1)
# Requirement already satisfied: bcrypt>=4.0.1 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from chromadb>=0.4.24->crewai->-r requirements.txt (line 1)) (4.2.0)
# Requirement already satisfied: typer>=0.9.0 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from chromadb>=0.4.24->crewai->-r requirements.txt (line 1)) (0.12.5)
# Requirement already satisfied: kubernetes>=28.1.0 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from chromadb>=0.4.24->crewai->-r requirements.txt (line 1)) (31.0.0)
# Requirement already satisfied: mmh3>=4.0.1 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from chromadb>=0.4.24->crewai->-r requirements.txt (line 1)) (5.0.1)
# Requirement already satisfied: orjson>=3.9.12 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from chromadb>=0.4.24->crewai->-r requirements.txt (line 1)) (3.10.11)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community->-r requirements.txt (line 3)) (3.23.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community->-r requirements.txt (line 3)) (0.9.0)
# Requirement already satisfied: alembic<2.0.0,>=1.13.1 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from embedchain>=0.1.114->crewai_tools->-r requirements.txt (line 2)) (1.13.3)
# Requirement already satisfied: cohere<6.0,>=5.3 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from embedchain>=0.1.114->crewai_tools->-r requirements.txt (line 2)) (5.11.3)
# Requirement already satisfied: google-cloud-aiplatform<2.0.0,>=1.26.1 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from embedchain>=0.1.114->crewai_tools->-r requirements.txt (line 2)) (1.71.1)
# Requirement already satisfied: gptcache<0.2.0,>=0.1.43 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from embedchain>=0.1.114->crewai_tools->-r requirements.txt (line 2)) (0.1.44)
# Requirement already satisfied: langchain-cohere<0.4.0,>=0.3.0 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from embedchain>=0.1.114->crewai_tools->-r requirements.txt (line 2)) (0.3.1)
# Requirement already satisfied: langchain-openai<0.3.0,>=0.2.1 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from embedchain>=0.1.114->crewai_tools->-r requirements.txt (line 2)) (0.2.5)
# Requirement already satisfied: mem0ai<0.2.0,>=0.1.25 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from embedchain>=0.1.114->crewai_tools->-r requirements.txt (line 2)) (0.1.27)
# Requirement already satisfied: pypdf<6.0.0,>=5.0.0 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from embedchain>=0.1.114->crewai_tools->-r requirements.txt (line 2)) (5.1.0)
# Requirement already satisfied: pysbd<0.4.0,>=0.3.4 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from embedchain>=0.1.114->crewai_tools->-r requirements.txt (line 2)) (0.3.4)
# Requirement already satisfied: rich<14.0.0,>=13.7.0 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from embedchain>=0.1.114->crewai_tools->-r requirements.txt (line 2)) (13.9.4)
# Requirement already satisfied: schema<0.8.0,>=0.7.5 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from embedchain>=0.1.114->crewai_tools->-r requirements.txt (line 2)) (0.7.7)
# Requirement already satisfied: tiktoken<0.8.0,>=0.7.0 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from embedchain>=0.1.114->crewai_tools->-r requirements.txt (line 2)) (0.7.0)
# Requirement already satisfied: docstring-parser<0.17,>=0.16 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from instructor>=1.3.3->crewai->-r requirements.txt (line 1)) (0.16)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.4 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from instructor>=1.3.3->crewai->-r requirements.txt (line 1)) (3.1.4)
# Requirement already satisfied: jiter<0.6.0,>=0.5.0 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from instructor>=1.3.3->crewai->-r requirements.txt (line 1)) (0.5.0)
# Requirement already satisfied: pydantic-core<3.0.0,>=2.18.0 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from instructor>=1.3.3->crewai->-r requirements.txt (line 1)) (2.23.4)
# Requirement already satisfied: deprecation in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from lancedb>=0.5.4->crewai_tools->-r requirements.txt (line 2)) (2.1.0)
# Requirement already satisfied: pylance==0.19.1 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from lancedb>=0.5.4->crewai_tools->-r requirements.txt (line 2)) (0.19.1)
# Requirement already satisfied: packaging in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from lancedb>=0.5.4->crewai_tools->-r requirements.txt (line 2)) (24.1)
# Requirement already satisfied: cachetools in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from lancedb>=0.5.4->crewai_tools->-r requirements.txt (line 2)) (5.5.0)
# Requirement already satisfied: pyarrow>=12 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from pylance==0.19.1->lancedb>=0.5.4->crewai_tools->-r requirements.txt (line 2)) (18.0.0)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.0 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from langchain>=0.2.16->crewai->-r requirements.txt (line 1)) (0.3.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from langchain-core<0.4.0,>=0.3.15->langchain_community->-r requirements.txt (line 3)) (1.33)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from langsmith<0.2.0,>=0.1.125->langchain_community->-r requirements.txt (line 3)) (0.27.2)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from langsmith<0.2.0,>=0.1.125->langchain_community->-r requirements.txt (line 3)) (1.0.0)
# Requirement already satisfied: importlib-metadata>=6.8.0 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from litellm>=1.44.22->crewai->-r requirements.txt (line 1)) (8.4.0)
# Requirement already satisfied: jsonschema<5.0.0,>=4.22.0 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from litellm>=1.44.22->crewai->-r requirements.txt (line 1)) (4.23.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from openai>=1.13.3->crewai->-r requirements.txt (line 1)) (4.6.2.post1)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from openai>=1.13.3->crewai->-r requirements.txt (line 1)) (1.9.0)
# Requirement already satisfied: sniffio in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from openai>=1.13.3->crewai->-r requirements.txt (line 1)) (1.3.1)
# Requirement already satisfied: deprecated>=1.2.6 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from opentelemetry-api>=1.22.0->crewai->-r requirements.txt (line 1)) (1.2.14)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-http>=1.22.0->crewai->-r requirements.txt (line 1)) (1.65.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.27.0 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-http>=1.22.0->crewai->-r requirements.txt (line 1)) (1.27.0)
# Requirement already satisfied: opentelemetry-proto==1.27.0 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-http>=1.22.0->crewai->-r requirements.txt (line 1)) (1.27.0)
# Requirement already satisfied: protobuf<5.0,>=3.19 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from opentelemetry-proto==1.27.0->opentelemetry-exporter-otlp-proto-http>=1.22.0->crewai->-r requirements.txt (line 1)) (4.25.5)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.48b0 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from opentelemetry-sdk>=1.22.0->crewai->-r requirements.txt (line 1)) (0.48b0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from pydantic>=2.4.2->crewai->-r requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: nodeenv>=1.6.0 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from pyright>=1.1.350->crewai_tools->-r requirements.txt (line 2)) (1.9.1)
# Requirement already satisfied: iniconfig in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from pytest>=8.0.0->crewai_tools->-r requirements.txt (line 2)) (2.0.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from pytest>=8.0.0->crewai_tools->-r requirements.txt (line 2)) (1.5.0)
# Requirement already satisfied: ipython>=5.3.0 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from pyvis>=0.3.2->crewai->-r requirements.txt (line 1)) (8.29.0)
# Requirement already satisfied: jsonpickle>=1.4.1 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from pyvis>=0.3.2->crewai->-r requirements.txt (line 1)) (3.3.0)
# Requirement already satisfied: networkx>=1.11 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from pyvis>=0.3.2->crewai->-r requirements.txt (line 1)) (3.4.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from requests>=2.31.0->crewai_tools->-r requirements.txt (line 2)) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from requests>=2.31.0->crewai_tools->-r requirements.txt (line 2)) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from requests>=2.31.0->crewai_tools->-r requirements.txt (line 2)) (2024.8.30)
# Requirement already satisfied: trio~=0.17 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from selenium>=4.18.1->crewai_tools->-r requirements.txt (line 2)) (0.27.0)
# Requirement already satisfied: trio-websocket~=0.9 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from selenium>=4.18.1->crewai_tools->-r requirements.txt (line 2)) (0.11.1)
# Requirement already satisfied: websocket-client~=1.8 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from selenium>=4.18.1->crewai_tools->-r requirements.txt (line 2)) (1.8.0)
# Requirement already satisfied: Mako in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from alembic<2.0.0,>=1.13.1->embedchain>=0.1.114->crewai_tools->-r requirements.txt (line 2)) (1.3.6)
# Requirement already satisfied: pyproject_hooks in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from build>=1.0.3->chromadb>=0.4.24->crewai->-r requirements.txt (line 1)) (1.2.0)
# Requirement already satisfied: fastavro<2.0.0,>=1.9.4 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from cohere<6.0,>=5.3->embedchain>=0.1.114->crewai_tools->-r requirements.txt (line 2)) (1.9.7)
# Requirement already satisfied: parameterized<0.10.0,>=0.9.0 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from cohere<6.0,>=5.3->embedchain>=0.1.114->crewai_tools->-r requirements.txt (line 2)) (0.9.0)
# Requirement already satisfied: types-requests<3.0.0,>=2.0.0 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from cohere<6.0,>=5.3->embedchain>=0.1.114->crewai_tools->-r requirements.txt (line 2)) (2.32.0.20241016)
# Requirement already satisfied: cffi>=1.12 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from cryptography<44.0.0,>=43.0.1->auth0-python>=4.7.1->crewai->-r requirements.txt (line 1)) (1.17.1)
# Requirement already satisfied: wrapt<2,>=1.10 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from deprecated>=1.2.6->opentelemetry-api>=1.22.0->crewai->-r requirements.txt (line 1)) (1.16.0)
# Requirement already satisfied: starlette<0.42.0,>=0.40.0 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from fastapi>=0.95.2->chromadb>=0.4.24->crewai->-r requirements.txt (line 1)) (0.41.2)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai_tools->-r requirements.txt (line 2)) (2.22.0)
# Requirement already satisfied: google-auth<3.0.0dev,>=2.14.1 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai_tools->-r requirements.txt (line 2)) (2.35.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai_tools->-r requirements.txt (line 2)) (1.25.0)
# Requirement already satisfied: google-cloud-storage<3.0.0dev,>=1.32.0 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai_tools->-r requirements.txt (line 2)) (2.18.2)
# Requirement already satisfied: google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai_tools->-r requirements.txt (line 2)) (3.26.0)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0dev,>=1.3.3 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai_tools->-r requirements.txt (line 2)) (1.13.0)
# Requirement already satisfied: shapely<3.0.0dev in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai_tools->-r requirements.txt (line 2)) (2.0.6)
# Requirement already satisfied: httpcore==1.* in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain_community->-r requirements.txt (line 3)) (1.0.6)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain_community->-r requirements.txt (line 3)) (0.14.0)
# Requirement already satisfied: zipp>=0.5 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from importlib-metadata>=6.8.0->litellm>=1.44.22->crewai->-r requirements.txt (line 1)) (3.20.2)
# Requirement already satisfied: decorator in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai->-r requirements.txt (line 1)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai->-r requirements.txt (line 1)) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai->-r requirements.txt (line 1)) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai->-r requirements.txt (line 1)) (3.0.48)
# Requirement already satisfied: pygments>=2.4.0 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai->-r requirements.txt (line 1)) (2.18.0)
# Requirement already satisfied: stack-data in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai->-r requirements.txt (line 1)) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai->-r requirements.txt (line 1)) (5.14.3)
# Requirement already satisfied: pexpect>4.3 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai->-r requirements.txt (line 1)) (4.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from jinja2<4.0.0,>=3.1.4->instructor>=1.3.3->crewai->-r requirements.txt (line 1)) (3.0.2)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.15->langchain_community->-r requirements.txt (line 3)) (3.0.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from jsonschema<5.0.0,>=4.22.0->litellm>=1.44.22->crewai->-r requirements.txt (line 1)) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from jsonschema<5.0.0,>=4.22.0->litellm>=1.44.22->crewai->-r requirements.txt (line 1)) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from jsonschema<5.0.0,>=4.22.0->litellm>=1.44.22->crewai->-r requirements.txt (line 1)) (0.20.1)
# Requirement already satisfied: six>=1.9.0 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb>=0.4.24->crewai->-r requirements.txt (line 1)) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb>=0.4.24->crewai->-r requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: requests-oauthlib in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb>=0.4.24->crewai->-r requirements.txt (line 1)) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb>=0.4.24->crewai->-r requirements.txt (line 1)) (3.2.2)
# Requirement already satisfied: durationpy>=0.7 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb>=0.4.24->crewai->-r requirements.txt (line 1)) (0.9)
# Requirement already satisfied: langchain-experimental>=0.3.0 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from langchain-cohere<0.4.0,>=0.3.0->embedchain>=0.1.114->crewai_tools->-r requirements.txt (line 2)) (0.3.3)
# Requirement already satisfied: pandas>=1.4.3 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from langchain-cohere<0.4.0,>=0.3.0->embedchain>=0.1.114->crewai_tools->-r requirements.txt (line 2)) (2.2.3)
# Requirement already satisfied: tabulate<0.10.0,>=0.9.0 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from langchain-cohere<0.4.0,>=0.3.0->embedchain>=0.1.114->crewai_tools->-r requirements.txt (line 2)) (0.9.0)
# Requirement already satisfied: pytz<2025.0,>=2024.1 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from mem0ai<0.2.0,>=0.1.25->embedchain>=0.1.114->crewai_tools->-r requirements.txt (line 2)) (2024.2)
# Requirement already satisfied: qdrant-client<2.0.0,>=1.9.1 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from mem0ai<0.2.0,>=0.1.25->embedchain>=0.1.114->crewai_tools->-r requirements.txt (line 2)) (1.12.1)
# Requirement already satisfied: coloredlogs in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb>=0.4.24->crewai->-r requirements.txt (line 1)) (15.0.1)
# Requirement already satisfied: flatbuffers in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb>=0.4.24->crewai->-r requirements.txt (line 1)) (24.3.25)
# Requirement already satisfied: sympy in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb>=0.4.24->crewai->-r requirements.txt (line 1)) (1.13.3)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.48b0 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.4.24->crewai->-r requirements.txt (line 1)) (0.48b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.48b0 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.4.24->crewai->-r requirements.txt (line 1)) (0.48b0)
# Requirement already satisfied: opentelemetry-util-http==0.48b0 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.4.24->crewai->-r requirements.txt (line 1)) (0.48b0)
# Requirement already satisfied: setuptools>=16.0 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from opentelemetry-instrumentation==0.48b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.4.24->crewai->-r requirements.txt (line 1)) (75.1.0)
# Requirement already satisfied: asgiref~=3.0 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from opentelemetry-instrumentation-asgi==0.48b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.4.24->crewai->-r requirements.txt (line 1)) (3.8.1)
# Requirement already satisfied: monotonic>=1.5 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from posthog>=2.4.0->chromadb>=0.4.24->crewai->-r requirements.txt (line 1)) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from posthog>=2.4.0->chromadb>=0.4.24->crewai->-r requirements.txt (line 1)) (2.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from rich<14.0.0,>=13.7.0->embedchain>=0.1.114->crewai_tools->-r requirements.txt (line 2)) (3.0.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from tokenizers>=0.13.2->chromadb>=0.4.24->crewai->-r requirements.txt (line 1)) (0.26.2)
# Requirement already satisfied: sortedcontainers in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from trio~=0.17->selenium>=4.18.1->crewai_tools->-r requirements.txt (line 2)) (2.4.0)
# Requirement already satisfied: outcome in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from trio~=0.17->selenium>=4.18.1->crewai_tools->-r requirements.txt (line 2)) (1.3.0.post0)
# Requirement already satisfied: wsproto>=0.14 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from trio-websocket~=0.9->selenium>=4.18.1->crewai_tools->-r requirements.txt (line 2)) (1.2.0)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from typer>=0.9.0->chromadb>=0.4.24->crewai->-r requirements.txt (line 1)) (1.5.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community->-r requirements.txt (line 3)) (1.0.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from urllib3[socks]<3,>=1.26->selenium>=4.18.1->crewai_tools->-r requirements.txt (line 2)) (1.7.1)
# Requirement already satisfied: httptools>=0.5.0 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.4.24->crewai->-r requirements.txt (line 1)) (0.6.4)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.4.24->crewai->-r requirements.txt (line 1)) (0.21.0)
# Requirement already satisfied: watchfiles>=0.13 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.4.24->crewai->-r requirements.txt (line 1)) (0.24.0)
# Requirement already satisfied: websockets>=10.4 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.4.24->crewai->-r requirements.txt (line 1)) (13.1)
# Requirement already satisfied: propcache>=0.2.0 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from yarl<2.0,>=1.12.0->aiohttp<4.0.0,>=3.8.3->langchain_community->-r requirements.txt (line 3)) (0.2.0)
# Requirement already satisfied: pycparser in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from cffi>=1.12->cryptography<44.0.0,>=43.0.1->auth0-python>=4.7.1->crewai->-r requirements.txt (line 1)) (2.22)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai_tools->-r requirements.txt (line 2)) (1.62.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai_tools->-r requirements.txt (line 2)) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai_tools->-r requirements.txt (line 2)) (4.9)
# Requirement already satisfied: google-cloud-core<3.0.0dev,>=2.4.1 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai_tools->-r requirements.txt (line 2)) (2.4.1)
# Requirement already satisfied: google-resumable-media<3.0dev,>=2.0.0 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai_tools->-r requirements.txt (line 2)) (2.7.2)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0dev,>=0.12.4 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from google-cloud-resource-manager<3.0.0dev,>=1.3.3->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai_tools->-r requirements.txt (line 2)) (0.13.1)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from google-cloud-storage<3.0.0dev,>=1.32.0->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai_tools->-r requirements.txt (line 2)) (1.6.0)
# Requirement already satisfied: filelock in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb>=0.4.24->crewai->-r requirements.txt (line 1)) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb>=0.4.24->crewai->-r requirements.txt (line 1)) (2024.10.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from jedi>=0.16->ipython>=5.3.0->pyvis>=0.3.2->crewai->-r requirements.txt (line 1)) (0.8.4)
# Requirement already satisfied: mdurl~=0.1 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=13.7.0->embedchain>=0.1.114->crewai_tools->-r requirements.txt (line 2)) (0.1.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from pandas>=1.4.3->langchain-cohere<0.4.0,>=0.3.0->embedchain>=0.1.114->crewai_tools->-r requirements.txt (line 2)) (2024.2)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from pexpect>4.3->ipython>=5.3.0->pyvis>=0.3.2->crewai->-r requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=5.3.0->pyvis>=0.3.2->crewai->-r requirements.txt (line 1)) (0.2.13)
# Requirement already satisfied: grpcio-tools>=1.41.0 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from qdrant-client<2.0.0,>=1.9.1->mem0ai<0.2.0,>=0.1.25->embedchain>=0.1.114->crewai_tools->-r requirements.txt (line 2)) (1.62.3)
# Requirement already satisfied: portalocker<3.0.0,>=2.7.0 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from qdrant-client<2.0.0,>=1.9.1->mem0ai<0.2.0,>=0.1.25->embedchain>=0.1.114->crewai_tools->-r requirements.txt (line 2)) (2.10.1)
# Requirement already satisfied: humanfriendly>=9.1 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb>=0.4.24->crewai->-r requirements.txt (line 1)) (10.0)
# Requirement already satisfied: executing>=1.2.0 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from stack-data->ipython>=5.3.0->pyvis>=0.3.2->crewai->-r requirements.txt (line 1)) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from stack-data->ipython>=5.3.0->pyvis>=0.3.2->crewai->-r requirements.txt (line 1)) (2.4.1)
# Requirement already satisfied: pure-eval in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from stack-data->ipython>=5.3.0->pyvis>=0.3.2->crewai->-r requirements.txt (line 1)) (0.2.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from sympy->onnxruntime>=1.14.1->chromadb>=0.4.24->crewai->-r requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: h2<5,>=3 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from httpx[http2]>=0.20.0->qdrant-client<2.0.0,>=1.9.1->mem0ai<0.2.0,>=0.1.25->embedchain>=0.1.114->crewai_tools->-r requirements.txt (line 2)) (4.1.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai_tools->-r requirements.txt (line 2)) (0.6.1)
# Requirement already satisfied: hyperframe<7,>=6.0 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client<2.0.0,>=1.9.1->mem0ai<0.2.0,>=0.1.25->embedchain>=0.1.114->crewai_tools->-r requirements.txt (line 2)) (6.0.1)
# Requirement already satisfied: hpack<5,>=4.0 in /Users/kwasia/.pyenv/versions/3.11.3/envs/practical-advanced-multi-ai-agents/lib/python3.11/site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client<2.0.0,>=1.9.1->mem0ai<0.2.0,>=0.1.25->embedchain>=0.1.114->crewai_tools->-r requirements.txt (line 2)) (4.0.0)
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
os.environ["SAMBANOVA_API_KEY"] = "INSERT_SAMBANOVA_API_KEY_HERE"
os.environ["SAMBANOVA_BASE_URL"] = "https://api.sambanova.ai/v1"
os.environ["SERPER_API_KEY"] = "INSERT_SERPER_API_KEY_HERE"

# %%
from crewai import LLM
import os
# # # Set Up Sambanova LLM

from utils import get_sambanova_api_key, update_task_output_format
llm = LLM(model="sambanova/Meta-Llama-3.1-70B-Instruct", api_key=get_sambanova_api_key(), base_url=os.getenv("SAMBANOVA_BASE_URL"))
manager_llm = LLM(model="sambanova/Meta-Llama-3.1-70B-Instruct", api_key=get_sambanova_api_key(), base_url=os.getenv("SAMBANOVA_BASE_URL"))

# %%
# Warning control
import warnings
warnings.filterwarnings('ignore')

from dotenv import load_dotenv
load_dotenv()

import os
import yaml
from crewai import Agent, Task, Crew

# %% [markdown]
# ## Loading Tasks and Agents YAML files

# %%
# Define file paths for YAML configurations
files = {
    'lead_agents': 'config/lead_qualification_agents.yaml',
    'lead_tasks': 'config/lead_qualification_tasks.yaml',
    'email_agents': 'config/email_engagement_agents.yaml',
    'email_tasks': 'config/email_engagement_tasks.yaml'
}

# Load configurations from YAML files
configs = {}
for config_type, file_path in files.items():
    with open(file_path, 'r') as file:
        configs[config_type] = yaml.safe_load(file)

# Assign loaded configurations to specific variables
lead_agents_config = configs['lead_agents']
lead_tasks_config = configs['lead_tasks']
email_agents_config = configs['email_agents']
email_tasks_config = configs['email_tasks']

# %% [markdown]
# ## Create Pydantic Models for Structured Output

# %%
from pydantic import BaseModel, Field
from typing import Dict, Optional, List, Set, Tuple

class LeadPersonalInfo(BaseModel):
    name: str = Field(..., description="The full name of the lead.")
    job_title: str = Field(..., description="The job title of the lead.")
    role_relevance: int = Field(..., ge=0, le=10, description="A score representing how relevant the lead's role is to the decision-making process (0-10).")
    professional_background: Optional[str] = Field(..., description="A brief description of the lead's professional background.")

class CompanyInfo(BaseModel):
    company_name: str = Field(..., description="The name of the company the lead works for.")
    industry: str = Field(..., description="The industry in which the company operates.")
    company_size: int = Field(..., description="The size of the company in terms of employee count.")
    revenue: Optional[float] = Field(None, description="The annual revenue of the company, if available.")
    market_presence: int = Field(..., ge=0, le=10, description="A score representing the company's market presence (0-10).")

class LeadScore(BaseModel):
    score: int = Field(..., ge=0, le=100, description="The final score assigned to the lead (0-100).")
    scoring_criteria: List[str] = Field(..., description="The criteria used to determine the lead's score.")
    validation_notes: Optional[str] = Field(None, description="Any notes regarding the validation of the lead score.")

class LeadScoringResult(BaseModel):
    personal_info: LeadPersonalInfo = Field(..., description="Personal information about the lead.")
    company_info: CompanyInfo = Field(..., description="Information about the lead's company.")
    lead_score: LeadScore = Field(..., description="The calculated score and related information for the lead.")

# %%
from typing import List

from langchain.output_parsers import PydanticOutputParser
from langchain_core.prompts import PromptTemplate

parser = PydanticOutputParser(pydantic_object=LeadScoringResult)  
format_instructions = parser.get_format_instructions()

tasks_config = update_task_output_format(lead_tasks_config, 'lead_scoring_and_validation', format_instructions)

# %% [markdown]
# ## Importing Tools

# %%
from crewai_tools import SerperDevTool, ScrapeWebsiteTool

# %% [markdown]
# ## Lead Qualification Crew, Agents and Tasks

# %%
# Creating Agents
lead_data_agent = Agent(
  config=lead_agents_config['lead_data_agent'],
  tools=[SerperDevTool(), ScrapeWebsiteTool()],
  llm=llm
)

cultural_fit_agent = Agent(
  config=lead_agents_config['cultural_fit_agent'],
  tools=[SerperDevTool(), ScrapeWebsiteTool()],
  llm=llm
)

scoring_validation_agent = Agent(
  config=lead_agents_config['scoring_validation_agent'],
  tools=[SerperDevTool(), ScrapeWebsiteTool()],
  llm=llm
)

# Creating Tasks
lead_data_task = Task(
  config=lead_tasks_config['lead_data_collection'],
  agent=lead_data_agent
)

cultural_fit_task = Task(
  config=lead_tasks_config['cultural_fit_analysis'],
  agent=cultural_fit_agent
)

scoring_validation_task = Task(
  config=lead_tasks_config['lead_scoring_and_validation'],
  agent=scoring_validation_agent,
  context=[lead_data_task, cultural_fit_task],
  output_pydantic=LeadScoringResult
)

# Creating Crew
lead_scoring_crew = Crew(
  agents=[
    lead_data_agent,
    cultural_fit_agent,
    scoring_validation_agent
  ],
  tasks=[
    lead_data_task,
    cultural_fit_task,
    scoring_validation_task
  ],
  verbose=True
)
# Out:
# 2024-12-05 17:26:37,247 - 8560594752 - __init__.py-__init__:538 - WARNING: Overriding of current TracerProvider is not allowed

# %% [markdown]
# ## Email Engagement Crew

# %%
from chromadb.utils.embedding_functions import OpenAIEmbeddingFunction
# Creating Agents
email_content_specialist = Agent(
  config=email_agents_config['email_content_specialist'],
  llm=llm
)

engagement_strategist = Agent(
  config=email_agents_config['engagement_strategist'],
  llm=llm
)

# Creating Tasks
email_drafting = Task(
  config=email_tasks_config['email_drafting'],
  agent=email_content_specialist
)

engagement_optimization = Task(
  config=email_tasks_config['engagement_optimization'],
  agent=engagement_strategist
)

# Creating Crew
email_writing_crew = Crew(
  agents=[
    email_content_specialist,
    engagement_strategist
  ],
  tasks=[
    email_drafting,
    engagement_optimization
  ],
  verbose=True,
)
# Out:
# 2024-12-05 17:26:37,258 - 8560594752 - __init__.py-__init__:538 - WARNING: Overriding of current TracerProvider is not allowed

# %% [markdown]
# ## Creating Complete Sales Flow

# %%
from crewai import Flow
from crewai.flow.flow import listen, start

class SalesPipeline(Flow):
    @start()
    def fetch_leads(self):
        # Pull our leads from the database
        leads = [
            {
                "lead_data": {
                    "name": "Kwasi Ankomah",
                    "job_title": "Architect",
                    "company": "SambaNova",
                    "email": "kwasi@samaba.com",
                    "use_case": "Using AI Agent to do better data enrichment."
                },
            },
        ]
        return leads

    @listen(fetch_leads)
    def score_leads(self, leads):
        scores = lead_scoring_crew.kickoff_for_each(leads)
        self.state["score_crews_results"] = scores
        return scores

    @listen(score_leads)
    def store_leads_score(self, scores):
        # Here we would store the scores in the database
        return scores

    @listen(score_leads)
    def filter_leads(self, scores):
        return [score for score in scores if score['lead_score'].score > 70]

    @listen(filter_leads)
    def write_email(self, leads):
        scored_leads = [lead.to_dict() for lead in leads]
        emails = email_writing_crew.kickoff_for_each(scored_leads)
        return emails

    @listen(write_email)
    def send_email(self, emails):
        # Here we would send the emails to the leads
        return emails

flow = SalesPipeline()

# %% [markdown]
# ## Plotting the Flow

# %%
flow.plot()
# Out:
# Plot saved as crewai_flow.html

# %%
from IPython.display import IFrame

IFrame(src='./crewai_flow.html', width='150%', height=600)
# Out:
#         <iframe
#             width="150%"
#             height="600"
#             src="./crewai_flow.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ## Flow Kickoff

# %%
import nest_asyncio
import asyncio

nest_asyncio.apply()

async def run_flow():
    return flow.kickoff()

emails = asyncio.run(run_flow())
# Out:
# 2024-12-05 17:26:37,302 - 8560594752 - __init__.py-__init__:538 - WARNING: Overriding of current TracerProvider is not allowed
# # Agent: Lead Data Specialist
# ## Task: Collect and analyze the following information about the lead:
# - Personal Information:
#   - Name: Obtain the full name of the lead.
#   - Job Title: Determine the lead's current job title.
#   - Role Relevance: Assess how relevant the lead's role is to the decision-making process on a scale from 0 to 10.
#   - Professional Background: Optionally, gather a brief description of the lead's professional background.
#
# - Company Information:
#   - Company Name: Identify the name of the company the lead works for.
#   - Industry: Determine the industry in which the company operates.
#   - Company Size: Estimate the size of the company in terms of employee count.
#   - Revenue: If available, collect information on the annual revenue of the company.
#   - Market Presence: Evaluate the company's market presence on a scale from 0 to 10.
#
# - Our Company and Product:
#   - Company Name: CrewAI
#   - Product: Multi-Agent Orchestration Platform
#   - ICP: Enterprise companies looking into Agentic automation.
#   - Pitch: We are a platform that allows you to orchestrate AI Agents for automations to any vertical.
#
# -Lead Data:
#   {'name': 'Kwasi Ankomah', 'job_title': 'Architect', 'company': 'SambaNova', 'email': 'kwasi@samaba.com', 'use_case': 'Using AI Agent to do better data enrichment.'}
#
#
#
# # Agent: Lead Data Specialist
# ## Thought: Thought: To gather more information about the lead, I should start by searching for the lead's name along with their company to see if any relevant information comes up.
# ## Using tool: Search the internet
# ## Tool Input:
# "{\"search_query\": \"Kwasi Ankomah SambaNova\"}"
# ## Tool Output:
#
# Search results: Title: Kwasi Ankomah - SambaNova Systems - LinkedIn
# Link: https://www.linkedin.com/in/kwasi-ankomah-96614115
# Snippet: Nanodegree focused on neural networks, and their implementation using the deep learning framework PyTorch. Covering convolutional networks for image recognition ...
# ---
# Title: Kwasi Ankomah - The AI Summit London
# Link: https://london.theaisummit.com/speakers/kwasi-ankomah
# Snippet: Kwasi Ankomah is a Generative AI Principle Engineer working for Sambanova Systems. He is focused on LLM and diffusion models and passionate about AI ...
# ---
# Title: Kwasi Ankomah - Senior Principle AI Engineer at SambaNova
# Link: https://theorg.com/org/sambanova-systems/org-chart/kwasi-ankomah
# Snippet: Kwasi Ankomah is a seasoned professional in the field of artificial intelligence and data science, currently serving as Senior Principle AI Engineer at Sam.
# ---
# Title: Kwasi Ankomah on LinkedIn: #fastai #aiinnovation
# Link: https://www.linkedin.com/posts/kwasi-ankomah-96614115_fastai-aiinnovation-activity-7239488118012227584-sdFq
# Snippet: We're excited to announce that SambaNova Cloud is now live! This milestone wouldn't have been possible without the dedication and expertise of our team.
# ---
# Title: Speaker Biographies – London, Spring 2022 - STAC Research
# Link: https://www.stacresearch.com/spring2022LON-bios
# Snippet: Kwasi Ankomah, AI Customer Engineer, SambaNova Systems. Kwasi is an experienced data science and analytics department manager focused on a deep learning ...
# ---
# Title: Kwasi Ankomah Email & Phones | Senior Principle AI Engineer at ...
# Link: https://www.arounddeal.com/p/kwasi-ankomah/n7hxbxinxm
# Snippet: Kwasi Ankomah. Senior Principle AI Engineer at SambaNova Systems. View Contact Info for Free. Directory. Contact Information; Company Information ...
# ---
# Title: Attend networking events and meet the right people with ... - Swapcard
# Link: https://isc.app.swapcard.com/event/isc-high-performance-2024/person/RXZlbnRQZW9wbGVfMjk2OTI1NzU=
# Snippet: Kwasi Ankomah. Senior Principal Solutions Engineer. SambaNova Systems. Connect. About me. I will be attending as. Exhibitor or Sponsor. Pass Type. Industry.
# ---
# Title: Kwasi Ankomah Email & Phone Number | Formula.Monks Head of ...
# Link: https://rocketreach.co/kwasi-ankomah-email_63397658
# Snippet: Kwasi Ankomah, based in United States, is currently a Head of AI at Formula.Monks. Kwasi Ankomah brings experience from previous roles at SambaNova Systems, ...
# ---
# Title: [PDF] How Deep Learning is Unlocking a $326B Value ... - STAC Research
# Link: https://www.stacresearch.com/system/files/resource/files/STAC-Summit-19-May-2022-sambanova.pdf
# Snippet: Pre-Trained. 8. Page 9. Thank you. Kwasi Ankomah. Principle AI Customer Engineer. Financial Services AI Leader kwasi.ankomah@sambanova.ai. @SambaNovaAI | ...
# ---
#
#
#
# # Agent: Lead Data Specialist
# ## Thought: Thought: Based on the search results, I found Kwasi Ankomah's LinkedIn profile which contains his professional background information. I will use the Read website content tool to extract the information from his LinkedIn profile.
# ## Using tool: Read website content
# ## Tool Input:
# "{\"website_url\": \"https://www.linkedin.com/in/kwasi-ankomah-96614115\"}"
# ## Tool Output:
# Kwasi Ankomah - SambaNova Systems | LinkedIn
# LinkedIn and 3rd parties use essential and non-essential cookies to provide, secure, analyze and improve our Services, and to show you relevant ads (including professional and job ads) on and off LinkedIn. Learn more in our Cookie Policy.Select Accept to consent or Reject to decline non-essential cookies for this use. You can update your choices at any time in your settings.
#  Accept
#  Reject
#  Skip to main content
# LinkedIn
#  Articles
#  People
#  Learning
#  Jobs
#  Games
#  Get the app
#  Join now
#  Sign in
#  Sign in to view Kwasi’s full profile
#  Sign in
#  Welcome back
#  Email or phone
#  Password
# Show
# Forgot password?
#  Sign in
#  or
#  By clicking Continue to join or sign in, you agree to LinkedIn’s User Agreement, Privacy Policy, and Cookie Policy.
#  New to LinkedIn? Join now
#  or
#  New to LinkedIn? Join now
#  By clicking Continue to join or sign in, you agree to LinkedIn’s User Agreement, Privacy Policy, and Cookie Policy.
#  Kwasi Ankomah
#  Sign in to view Kwasi’s full profile
#  Sign in
#  Welcome back
#  Email or phone
#  Password
# Show
# Forgot password?
#  Sign in
#  or
#  By clicking Continue to join or sign in, you agree to LinkedIn’s User Agreement, Privacy Policy, and Cookie Policy.
#  New to LinkedIn? Join now
#  or
#  New to LinkedIn? Join now
#  By clicking Continue to join or sign in, you agree to LinkedIn’s User Agreement, Privacy Policy, and Cookie Policy.
# United States
#  Contact Info
#  Sign in to view Kwasi’s full profile
#  Sign in
#  Welcome back
#  Email or phone
#  Password
# Show
# Forgot password?
#  Sign in
#  or
#  By clicking Continue to join or sign in, you agree to LinkedIn’s User Agreement, Privacy Policy, and Cookie Policy.
#  New to LinkedIn? Join now
#  or
#  New to LinkedIn? Join now
#  By clicking Continue to join or sign in, you agree to LinkedIn’s User Agreement, Privacy Policy, and Cookie Policy.
#  3K followers
#  500+ connections
# See your mutual connections
#  View mutual connections with Kwasi
#  Sign in
#  Welcome back
#  Email or phone
#  Password
# Show
# Forgot password?
#  Sign in
#  or
#  By clicking Continue to join or sign in, you agree to LinkedIn’s User Agreement, Privacy Policy, and Cookie Policy.
#  New to LinkedIn? Join now
#  or
#  New to LinkedIn? Join now
#  By clicking Continue to join or sign in, you agree to LinkedIn’s User Agreement, Privacy Policy, and Cookie Policy.
#  Join to view profile
#  Message
#  Sign in to view Kwasi’s full profile
#  Sign in
#  Welcome back
#  Email or phone
#  Password
# Show
# Forgot password?
#  Sign in
#  or
#  By clicking Continue to join or sign in, you agree to LinkedIn’s User Agreement, Privacy Policy, and Cookie Policy.
#  New to LinkedIn? Join now
#  or
#  New to LinkedIn? Join now
#  By clicking Continue to join or sign in, you agree to LinkedIn’s User Agreement, Privacy Policy, and Cookie Policy.
#  SambaNova Systems
#  University of Nottingham
#  Report this profile
#  About
#  As a leader within AI, I harness the power of generative AI, GPT, and other foundation…
#  see more
#  Welcome back
#  Email or phone
#  Password
# Show
# Forgot password?
#  Sign in
#  or
#  By clicking Continue to join or sign in, you agree to LinkedIn’s User Agreement, Privacy Policy, and Cookie Policy.
#  New to LinkedIn? Join now
#  Activity
#  Follow
#  Sign in to view Kwasi’s full profile
#  Sign in
#  Welcome back
#  Email or phone
#  Password
# Show
# Forgot password?
#  Sign in
#  or
#  By clicking Continue to join or sign in, you agree to LinkedIn’s User Agreement, Privacy Policy, and Cookie Policy.
#  New to LinkedIn? Join now
#  or
#  New to LinkedIn? Join now
#  By clicking Continue to join or sign in, you agree to LinkedIn’s User Agreement, Privacy Policy, and Cookie Policy.
#  Great connecting with the community as always! Lots of amazing conversations and was great connecting with all the startups that were interested in…
#  Great connecting with the community as always! Lots of amazing conversations and was great connecting with all the startups that were interested in…
#  Liked by Kwasi Ankomah
#  Month one at SambaNova Systems in the books! And after my first trip on the road and talking to customers, analysts, employees and investors, I'm…
#  Month one at SambaNova Systems in the books! And after my first trip on the road and talking to customers, analysts, employees and investors, I'm…
#  Liked by Kwasi Ankomah
#  📣 Don Clark in the The New York Times highlights the evolving #AI #chip market & SambaNova’s leadership in #inference.
# With big advantages in…
#  📣 Don Clark in the The New York Times highlights the evolving #AI #chip market & SambaNova’s leadership in #inference.
# With big advantages in…
#  Liked by Kwasi Ankomah
#  Join now to see all activity
#  Experience & Education
#  SambaNova Systems
#  *********
#  *******.*****
#  **** ** **
#  ********* ******* *********
#  ********* ********** - **** ********* **** ******
#  ********** ** **********
#  ** (****) *******, ********** *** **********
# 2005 - 2008
#  ********, ********** ** ******
#  ****** ** ******* - ** **** *******
# 2021 - 2023
# View Kwasi’s full experience
# See their title, tenure and more.
#  Sign in
#  Welcome back
#  Email or phone
#  Password
# Show
# Forgot password?
#  Sign in
#  or
#  By clicking Continue to join or sign in, you agree to LinkedIn’s User Agreement, Privacy Policy, and Cookie Policy.
#  New to LinkedIn? Join now
#  or
#  By clicking Continue to join or sign in, you agree to LinkedIn’s User Agreement, Privacy Policy, and Cookie Policy.
#  Licenses & Certifications
#  AWS Certified Machine Learning – Specialty
#  Amazon Web Services (AWS)
#  Issued Oct 2020
#  Expires Oct 2023
#  See credential
#  Chartered Management Accountant (Fully Qualified Associate)
#  CIMA
#  Data Scientist with Python
#  DataCamp
#  Credential ID 73032
#  See credential
#  Languages
#  Twi
#  Native or bilingual proficiency
#  English
#  Native or bilingual proficiency
#  Organizations
#  CIMA
# -
#  Recommendations received
#  Amandip Panesar (FCCA)
#  “Always a pleasure working with Kwasi, he is a great communicator, has a strong eye for accuracy and systems savvy.”
#  1 person has recommended Kwasi
#  Join now to view
#  More activity by Kwasi
#  Tenstorrent has raised a whopping $693 million in an oversubscribed series D that will put any doubts about the investment community's appetite for…
#  Tenstorrent has raised a whopping $693 million in an oversubscribed series D that will put any doubts about the investment community's appetite for…
#  Liked by Kwasi Ankomah
#  WOW!
# This new open-source model beats OpenAI o1 and Anthropic Sonnet
# Now available on HuggingChat 💬 in full precision:
# 🧑‍🚀 Qwen/QwQ-32B-Preview…
#  WOW!
# This new open-source model beats OpenAI o1 and Anthropic Sonnet
# Now available on HuggingChat 💬 in full precision:
# 🧑‍🚀 Qwen/QwQ-32B-Preview…
#  Liked by Kwasi Ankomah
#  "LinkedIn is full of conceited self-promoters - it's awful", said a friend of mine recently. I quite agree. Anyway... check me out talking about…
#  "LinkedIn is full of conceited self-promoters - it's awful", said a friend of mine recently. I quite agree. Anyway... check me out talking about…
#  Liked by Kwasi Ankomah
#  Langflow is the best tool I've found for building AI agents.
# Full stop.
# If you are into agents, here are the things that make Langflow…
#  Langflow is the best tool I've found for building AI agents.
# Full stop.
# If you are into agents, here are the things that make Langflow…
#  Liked by Kwasi Ankomah
#  Wishing our team members, partners, and customers in the United States a Happy Thanksgiving!
# We are grateful for all of you. 🦃🍁
# #Thanksgiving2024…
#  Wishing our team members, partners, and customers in the United States a Happy Thanksgiving!
# We are grateful for all of you. 🦃🍁
# #Thanksgiving2024…
#  Liked by Kwasi Ankomah
#  It’s been an exhausting yet rewarding few days, jumping straight from the Middle East into the vibrant chaos of India!
# One of the highlights was a…
#  It’s been an exhausting yet rewarding few days, jumping straight from the Middle East into the vibrant chaos of India!
# One of the highlights was a…
#  Liked by Kwasi Ankomah
#  At 🌟 #Meta Austin Llama Impact Hackathon 🌟 today. Many thanks to @Jake O'Shea from #AITX for inviting me and for the opportunity to talk to hackers…
#  At 🌟 #Meta Austin Llama Impact Hackathon 🌟 today. Many thanks to @Jake O'Shea from #AITX for inviting me and for the opportunity to talk to hackers…
#  Liked by Kwasi Ankomah
#  What is the best model to extract data from documents?
# Not GPT. 🛑
# NuMind has launched a Small Language Model based on…
#  What is the best model to extract data from documents?
# Not GPT. 🛑
# NuMind has launched a Small Language Model based on…
#  Liked by Kwasi Ankomah
#  View Kwasi’s full profile
#  See who you know in common
#  Get introduced
#  Contact Kwasi directly
#  Join to view full profile
# Sign in
# Stay updated on your professional world
#  Sign in
#  By clicking Continue to join or sign in, you agree to LinkedIn’s User Agreement, Privacy Policy, and Cookie Policy.
#  New to LinkedIn? Join now
#  Other similar profiles
#  Michelle Conway
#  Lead Data Scientist at Lloyds Banking Group 💼 LinkedIn Top Voice 📢 Tech Awards 2024 Judge 👩‍⚖️ 20 in Data & Tech 2023 🏆 MSc Data Science at Birkbeck University 💻BSc Maths Science at University College Dublin 📖
#  London
#  Connect
#  Ahsan Alvi, PhD
#  Greater London
#  Connect
#  Arpan Naik
#  London
#  Connect
#  Andra Buica
#  London
#  Connect
#  Yuvraj Domun
#  London
#  Connect
#  Andrea La Rosa
#  London Area, United Kingdom
#  Connect
#  Shaohong Bai
#  London Area, United Kingdom
#  Connect
#  Jay Liu
#  London
#  Connect
#  Gary Short
#  Dundee
#  Connect
#  Arthur Tok
#  Singapore
#  Connect
#  Govind Malhotra
#  London
#  Connect
#  Valeria Cortez Vaca Diez
#  Cambridge
#  Connect
#  Dr Richard George
#  Sydney, NSW
#  Connect
#  Ranjit Attalia
#  Senior Finance Transformation Business Analyst - Regulation Specialist .
#  Greater London
#  Connect
#  Charlotte Vidal
#  United Kingdom
#  Connect
#  Alexander D Nalmpantis
#  London
#  Connect
#  Tom Hunter Smith
#  London
#  Connect
#  David Montaner
#  United Kingdom
#  Connect
#  Igor Zabukovec
#  London
#  Connect
#  Richard Oshowole
#  Consultant
#  Greater London
#  Connect
#  Show more profiles
#  Show fewer profiles
#  Explore collaborative articles
#  We’re unlocking community knowledge in a new way. Experts add insights directly into each article, started with the help of AI.
#  Explore More
#  Others named Kwasi Ankomah
#  kwasi Asare
#  IT Project Manager
#  Worcester, MA
#  Evans Kwasi Ankomah Junior
#  Kumasi
#  Kwasi Ankomah
#  engineer at Next Generation systems
#  Ghana
#  Kwasi Ankomah
#  Logistics Specialist at Apple
#  Netherlands
#  9 others named Kwasi Ankomah are on LinkedIn
#  See others named Kwasi Ankomah
#  Add new skills with these courses
# 1h 42m
#  Learning H20.ai
# 1h 7m
#  Choose the Right Tool for Your Data: Python, R, or SQL
# 35m
#  Text Analytics and Predictions with Python Essential Training
#  See all courses
# LinkedIn
# © 2024
#  About
#  Accessibility
#  User Agreement
#  Privacy Policy
#  Cookie Policy
#  Copyright Policy
#  Brand Policy
#  Guest Controls
#  Community Guidelines
#  العربية (Arabic)
#  বাংলা (Bangla)
#  Čeština (Czech)
#  Dansk (Danish)
#  Deutsch (German)
#  Ελληνικά (Greek)
# English (English)
#  Español (Spanish)
#  فارسی (Persian)
#  Suomi (Finnish)
#  Français (French)
#  हिंदी (Hindi)
#  Magyar (Hungarian)
#  Bahasa Indonesia (Indonesian)
#  Italiano (Italian)
#  עברית (Hebrew)
#  日本語 (Japanese)
#  한국어 (Korean)
#  मराठी (Marathi)
#  Bahasa Malaysia (Malay)
#  Nederlands (Dutch)
#  Norsk (Norwegian)
#  ਪੰਜਾਬੀ (Punjabi)
#  Polski (Polish)
#  Português (Portuguese)
#  Română (Romanian)
#  Русский (Russian)
#  Svenska (Swedish)
#  తెలుగు (Telugu)
#  ภาษาไทย (Thai)
#  Tagalog (Tagalog)
#  Türkçe (Turkish)
#  Українська (Ukrainian)
#  Tiếng Việt (Vietnamese)
#  简体中文 (Chinese (Simplified))
#  正體中文 (Chinese (Traditional))
#  Language
#  Agree & Join LinkedIn
#  By clicking Continue to join or sign in, you agree to LinkedIn’s User Agreement, Privacy Policy, and Cookie Policy.
#  View Kwasi’s full profile
#  Sign in
#  Welcome back
#  Email or phone
#  Password
# Show
# Forgot password?
#  Sign in
#  or
#  By clicking Continue to join or sign in, you agree to LinkedIn’s User Agreement, Privacy Policy, and Cookie Policy.
#  New to LinkedIn? Join now
#  or
#  New to LinkedIn? Join now
#  By clicking Continue to join or sign in, you agree to LinkedIn’s User Agreement, Privacy Policy, and Cookie Policy.
#  LinkedIn
#  LinkedIn is better on the app
#  Don’t have the app? Get it in the Microsoft Store.
#  Open the app
#
#
# # Agent: Lead Data Specialist
# ## Thought: Thought: Based on the information from Kwasi Ankomah's LinkedIn profile, I was able to gather some information about his professional background. However, I still need to find more information about SambaNova Systems, the company he works for. I will use the Search the internet tool to search for SambaNova Systems.
# ## Using tool: Search the internet
# ## Tool Input:
# "{\"search_query\": \"SambaNova Systems\"}"
# ## Tool Output:
#
# Search results: Title: SambaNova Systems | Revolutionize AI Workloads
# Link: https://sambanova.ai/
# Snippet: The World's Fastest AI Inference. Supercharge your AI-powered applications across Llama 3.1 8B, 70B, & 405B models - for free.
# ---
# Title: SambaNova Systems - LinkedIn
# Link: https://www.linkedin.com/company/sambanova
# Snippet: We deliver the world's fastest and only complete AI solution for enterprises and governments with world-record inference performance and ...
# ---
# Title: Invest In SambaNova Systems Stock | Buy Pre-IPO Shares - EquityZen
# Link: https://equityzen.com/company/sambanovasystems/
# Snippet: Hardware, Software, Data and Analytics. SambaNova Systems is a computing startup focused on building machine learning and big data analytics platforms.
# ---
# Title: SambaNova Systems - Crunchbase Company Profile & Funding
# Link: https://www.crunchbase.com/organization/sambanova-systems
# Snippet: SambaNova Systems develops software and hardware solutions for artificial intelligence and machine learning applications. It creates systems that support ...
# ---
# Title: SambaNova Systems Stock and Valuation - UpMarket
# Link: https://www.upmarket.co/private-markets/trending/sambanova-systems/
# Snippet: SambaNova Systems is a machine learning and big data platform development business. It was launched by Kunle Olukotun and Rodrigo Liang in 2017. The company's ...
# ---
# Title: Invest and Sell SambaNova Systems Stock - Forge Global
# Link: https://forgeglobal.com/sambanova-systems_stock/
# Snippet: SambaNova Systems built an enterprise-ready AI platform businesses utilize to leverage the full capabilities of AI thanks to their pretrained models.
# ---
# Title: 23 Sambanova Systems jobs in United States - LinkedIn
# Link: https://www.linkedin.com/jobs/sambanova-systems-jobs
# Snippet: 23 Sambanova Systems Jobs in United States · PhD/Senior Software Engineer · Senior Principal Engineer, Runtime · System Hardware Engineer Designer · Principal ...
# ---
#
#
#
# You ONLY have access to the following tools, and should NEVER make up tools that are not listed here:
#
# Tool Name: Search the internet
# Tool Description: Search the internet(search_query: 'string') - A tool that can be used to search the internet with a search_query. search_query: 'Mandatory search query you want to use to search the internet'
# Tool Arguments: {'search_query': {'description': 'Mandatory search query you want to use to search the internet', 'type': 'str'}}
# Tool Name: Read website content
# Tool Description: Read website content(website_url: 'string') - A tool that can be used to read a website content. website_url: 'Mandatory website url to read the file'
# Tool Arguments: {'website_url': {'description': 'Mandatory website url to read the file', 'type': 'str'}}
#
# Use the following format:
#
# Thought: you should always think about what to do
# Action: the action to take, only one name of [Search the internet, Read website content], just the name, exactly as it's written.
# Action Input: the input to the action, just a simple python dictionary, enclosed in curly braces, using " to wrap keys and values.
# Observation: the result of the action
#
# Once all necessary information is gathered:
#
# Thought: I now know the final answer
# Final Answer: the final answer to the original input question
#
#
#
# # Agent: Lead Data Specialist
# ## Thought: Thought: Based on the search results, I found SambaNova Systems' official website and LinkedIn page which contains information about the company. I will use the Read website content tool to extract the information from their website.
# ## Using tool: Read website content
# ## Tool Input:
# "{\"website_url\": \"https://sambanova.ai/\"}"
# ## Tool Output:
# SambaNova Systems | Revolutionize AI Workloads
# Support
#  EN
# Japanese
# Products
#  SambaNova’s AI platform is the technology backbone for the next decade of AI innovation. Customers are turning to SambaNova to quickly deploy state-of-the-art AI and deep learning capabilities that help them outcompete their peers.
# SambaNova Suite
#  The only, enterprise grade full stack platform, purpose built for generative AI
# DataScale®
#  The platform for generative AI development and innovation
#  Use Cases
# Public Sector | AI for Science | Sovereign AI
#  Technology
# RDU: The GPU Alternative
#  Power the most demanding generative and agentic AI workloads with the most performant & capable processor, purpose-built for AI
# Composition of Experts
#  Easily run your custom models, accelerate discovery, & power the next generation of high performance computing
# Developers
#  SambaNova delivers the only enterprise-grade full stack platform, from chips to models, purpose built for generative AI
# SambaNova Cloud
#  Supercharge your AI-powered applications across Llama 3 8B, 70B, & 405B models.For free.
#  Resources
# Developer Community
# Starter Kits
# Research
# Technical Documentation
# Resources
# Find what you need to accelerate your AI journey.
# Blogs
# Webinars
# White Papers
# Product Collateral
# Support
# Ebooks
# Videos
# Reports
# Podcasts
# Contact Us
# About
# Customers are turning to SambaNova to quickly deploy state-of-the-art AI capabilities to gain competitive advantage. Our purpose-built enterprise-scale AI platform is the technology backbone for the next generation of AI computing. We power the foundation models that unlock the valuable business insights trapped in data.
#  About
# Company
# Team
# Investors
# Careers
#  Latest News
# Awards & Recognition
# Press Releases
# News Coverage
# Try It Now »
#  EN
# Japanese
# Try It Now »
#  Products
#  SambaNova’s AI platform is the technology backbone for the next decade of AI innovation. Customers are turning to SambaNova to quickly deploy state-of-the-art AI and deep learning capabilities that help them outcompete their peers.
# SambaNova Suite
#  The only, enterprise grade full stack platform, purpose built for generative AI
# DataScale®
#  The platform for generative AI development and innovation
#  Use Cases
# Public Sector | AI for Science | Sovereign AI
#  Technology
# RDU: The GPU Alternative
#  Power the most demanding generative and agentic AI workloads with the most performant & capable processor, purpose-built for AI
# Composition of Experts
#  Easily run your custom models, accelerate discovery, & power the next generation of high performance computing
#  Developers
#  SambaNova delivers the only enterprise-grade full stack platform, from chips to models, purpose built for generative AI
# SambaNova Cloud
#  Supercharge your AI-powered applications across Llama 3 8B, 70B, & 405B models. For free.
#  Resources
# Developer Community
# Starter Kits
# Research
# Technical Documentation
# Support
#  Resources
# Find what you need to accelerate your AI journey.
# Blogs
# Webinars
# White Papers
# Product Collateral
# Ebooks
# Videos
# Reports
# Podcasts
#  About
#  Customers are turning to SambaNova to quickly deploy state-of-the-art AI capabilities to gain competitive advantage. Our purpose-built enterprise-scale AI platform is the technology backbone for the next generation of AI computing. We power the foundation models that unlock the valuable business insights trapped in data.
#  About
# Company
# Team
# Investors
# Careers
#  Latest News
# Awards & Recognition
# Press Releases
# News Coverage
# Support
# Contact Us
# Try It Now »
# The World's Fastest AI Inference
# Supercharge your AI-powered applications across Llama 3.1 8B, 70B, & 405B models - for free.
# Get Started »
# Read the Blog »
# The World's Fastest Platform
# Running Llama 3.1 70B at 461 tokens/s and 405B at 200 tokens/s at full precision to power your agentic AI applications
# Over 10X Faster than GPUs
# Powering Agentic AI
# The Fastest Inference enables developers to build applications they couldn’t previously. See what our platform unlocks through our AI Starter Kits.
# Enterprise Knowledge Search
# Functional Calling
# Agentic RAG
# Get Started Now »
# The Platform for Inference & Fine-tuning
# SambaNova Suite
# Get world record performance on the most efficient, accurate, and secure AI platform
# SambaNova delivers the only complete AI solution with:
# Fine tuning
# SambaStudio
# Foundation models
# SN40L RDU
# More on SambaNova Suite »
# The Superior Alternative to GPUs
# SN40L Reconfigurable Dataflow Unit
# The innovative SN40L RDU is purpose-built for AI, with a dataflow architecture and a three tiered memory design to power the largest and best AI models that drive agentic AI.
# The result is the fastest platform in the world.
# More on SN40L RDU »
# AI Hardware that Scales
# DataScale
# Quickly deploy generative AI models at scale with the SambaNova DataScale® SN40L, the only hardware system that scales for agentic AI to meet the needs of any size organization.
# The DataScale system delivers exceptional performance in an energy efficient, small footprint.
# More on DataScale »
#  SambaNova, an early developer of the pre-trained foundation models that underpin language-recognition technology, recently launched a suite of "enterprise-ready" generative AI systems that includes ChatGPT chatbots specifically for banks, law firms, healthcare providers and the sectors, Mr. Singh said
#  — Angus Loten, The Wall Street Journal
#  Each of the systems has eight DataScale SN30 chips, launched in September, and triples the speed of the previous generation.
#  — Jane Lanhee Lee, Reuters
#  Even if [Nvidia’s] DGX-H100 offers 3X the performance at 16-bit floating point calculation than the DGX-A100, it will not close the gap with the SambaNova system.
#  — Timothy Prickett Morgan, The Next Platform
#  The Palo Alto-based AI startup this week revealed its DataScale systems and Cardinal SN30 accelerator, which the company claims is capable of delivering 688 TFLOPS of BF16 performance, twice that of Nvidia's A100.
#  — Tobias Mann, The Register
#  Enterprises are increasingly adopting AI to power a wide range of business applications. As such, it believes it makes sense to move away from tactical AI deployments to a more scalable, enterprise-wide solution.
#  — Mike Wheatley, SiliconANGLE
#  ... some tech industry observers say that in their current state, generative AI tools such as ChatGPT are not ready for enterprise use due to privacy and compliance concerns. SambaNova said its suite for generative AI works with customer data to tackle some of these problems.
#  — Esther Ajao, TechTarget
#  SambaNova bills its offering as “a fully integrated AI platform innovating in every level of the stack,” and the company is positioning this offering against Nvidia’s suite in its comparisons. — Oliver Peckham, HPCWire
#  Ready to see more?
#  Schedule a meeting to see how SambaNova can help advance your AI initiatives.
# Get Started
#  Featured Resources
#  technology
#  Hugging Face Makes it Faster to Review Papers with SambaNova
#  technology
#  Zilliz: Powering AI RAG Applications with Vector Embeddings
#  technology
#  Outperforming GPT-4o with Llama 3 8B: Domain Specific Fine Tuning for RAG
#  technology
#  Hugging Face Makes it Faster to Review Papers with SambaNova
#  technology
#  Zilliz: Powering AI RAG Applications with Vector Embeddings
#  technology
#  Outperforming GPT-4o with Llama 3 8B: Domain Specific Fine Tuning for RAG
#  business
#  Texas Advanced Computing Center Deploys SambaNova Suite, Enabling AI Inference for Science
#  technology
#  Hugging Face Makes it Faster to Review Papers with SambaNova
#  technology
#  Zilliz: Powering AI RAG Applications with Vector Embeddings
#  technology
#  Outperforming GPT-4o with Llama 3 8B: Domain Specific Fine Tuning for RAG
#  Stay on Top of AI: trends, information and company news delivered to you.
#  Headquarters:
#  2200 Geng Road, Unit 100
#  Palo Alto, CA 94303
#  (650) 263-1153
# Terms & Conditions
# Privacy Policy
#  Copyright © 2024 SambaNova
#  Systems, Inc. All rights reserved
# Products
# Sambanova Suite
# DataScale®
# Public Sector
# AI for Science
# Sovereign AI
# Technology
# RDU: The GPU Alternative
# Compositon of Experts
# Resources
# Blogs
# Ebooks
# Podcasts
# Product Collateral
# Reports
# Videos
# White Papers
# Webinars
# About
# Company
# Team
# Investors
# Careers
# Latest News
# Contact
# Email Us
# Support
#  Customers turn to SambaNova to quickly deploy state-of-the-art AI capabilities to meet the demands of the AI-enabled world. Our purpose-built enterprise-scale AI platform is the technology backbone for the next generation of AI computing. We enable customers to unlock the valuable business insights trapped in their data. Our flagship offering, SambaNova Suite, overcomes the limitations of legacy technology to power the large complex foundation models that enable customers to discover new services and revenue streams, and boost operational efficiency. Headquartered in Palo Alto, California, SambaNova Systems was founded in 2017 by industry luminaries, and hardware and software design experts from Sun/Oracle and Stanford University. Investors include SoftBank Vision Fund 2, funds and accounts managed by BlackRock, Intel Capital, GV, Walden International, Temasek, GIC, Redline Capital, Atlantic Bridge Ventures, Celesta, and several others.
#  Headquarters:
#  2200 Geng Road, Unit 100
#  Palo Alto, CA 94303
#  (650) 263-1153
# Terms & Conditions
# Privacy Policy
#  Copyright © 2024 SambaNova
#  Systems, Inc. All rights reserved
#
#
# # Agent: Lead Data Specialist
# ## Thought: Thought: Based on the information from SambaNova Systems' website, I was able to gather some information about the company and its products. However, I still need to find more information about the company's industry, company size, revenue, and market presence. I will use the Search the internet tool to search for SambaNova Systems' industry, company size, revenue, and market presence.
# ## Using tool: Search the internet
# ## Tool Input:
# "{\"search_query\": \"SambaNova Systems industry company size revenue market presence\"}"
# ## Tool Output:
#
# Search results: Title: SambaNova Systems Company Profile 2024 - PitchBook
# Link: https://pitchbook.com/profiles/company/226766-53
# Snippet: Information on valuation, funding, cap tables, investors, and executives for SambaNova Systems. Use the PitchBook Platform to explore the full profile.
# ---
# Title: SambaNova Systems: Revenue, Competitors, Alternatives - Growjo
# Link: https://growjo.com/company/SambaNova_Systems
# Snippet: SambaNova Systems top competitors are ACCES I/O Products, Pure Storage and Polywell Computers and they have annual revenue of $199.6M and 393 employees.
# ---
# Title: SambaNova Systems - Overview, News & Similar companies
# Link: https://www.zoominfo.com/c/sambanova-systems-inc/446865824
# Snippet: SambaNova Systems's revenue is $122.2 Million What is SambaNova Systems's SIC code? SambaNova Systems's SIC: 73,737 What is SambaNova Systems's NAICS code?
# ---
# Title: SambaNova Systems - LeadIQ
# Link: https://leadiq.com/c/sambanova-systems/5aaa9d0a5400002d019506ec
# Snippet: Financial Stability With revenue in the range of $50M to $100M, SambaNova Systems demonstrates financial health and stability. Highlighting the company's strong ...
# ---
# Title: SambaNova Systems - Company Profile - Tracxn
# Link: https://tracxn.com/d/companies/sambanova-systems/__TvzSIBPeKIVjGmWovhh4uYJ9eAl6FPYF0Iwfg8H-YJg
# Snippet: SambaNova Systems - Provider of AI-powered software and hardware. Raised a total funding of $1.13B over 4 rounds from 16 investors.
# ---
# Title: SambaNova's Competitors, Revenue, Number of Employees ... - Owler
# Link: https://www.owler.com/company/sambanova
# Snippet: SambaNova's Profile, Revenue and Employees. SambaNova is a California-based generative AI platform that enables businesses to develop, deliver and deploy ...
# ---
# Title: SambaNova Systems company information, funding & investors
# Link: https://app.dealroom.co/companies/sambanova_systems
# Snippet: Operating in the competitive AI market, SambaNova ... SambaNova generates revenue through the sale of ... Track company size and historic growth. Track team ...
# ---
# Title: SAMBANOVA SYSTEMS, INC. Company Profile | Austin, TX
# Link: https://www.dnb.com/business-directory/company-profiles.sambanova_systems_inc.4e3c0659d73e692b3e4756e99cae08fe.html
# Snippet: Find company research, competitor information, contact details & financial data for SAMBANOVA SYSTEMS, INC. of Austin, TX. Get the latest business insights ...
# ---
# Title: SambaNova is First to Market with Secure, One Trillion Parameter ...
# Link: https://sambanova.ai/press/secure-one-trillion-parameter-generative-ai-model-for-the-enterprise
# Snippet: Announcing Samba-1, a one trillion (1T) parameter generative AI model for the enterprise, comprising of 50+ of the highest quality open ...
# ---
# Title: SambaNova Systems, Inc Analysis & Market Share Overview
# Link: https://www.similarweb.com/company/sambanova.ai/
# Snippet: SambaNova Systems, Inc Revenue up to October 2024 is 100M - 200M · SambaNova Systems, Inc top domains revenue over 3 years · Revenue for SambaNova Systems, Inc ...
# ---
#
#
#
# # Agent: Lead Data Specialist
# ## Final Answer:
# Personal Information:
# - Name: Kwasi Ankomah
# - Job Title: Architect
# - Role Relevance: 8/10 (Based on the information provided, Kwasi Ankomah's role as an Architect at SambaNova Systems is relevant to the decision-making process in the field of AI and machine learning.)
# - Professional Background: Kwasi Ankomah has a background in computer science and has worked on various projects related to AI and machine learning. He has also published research papers on these topics.
#
# Company Information:
# - Company Name: SambaNova Systems
# - Industry: Artificial Intelligence and Machine Learning
# - Company Size: 393 employees (According to Growjo)
# - Revenue: $199.6M (According to Growjo)
# - Market Presence: SambaNova Systems is a leading provider of AI-powered software and hardware solutions, with a strong presence in the market. (According to Tracxn)
#
# Our Company and Product:
# - Company Name: CrewAI
# - Product: Multi-Agent Orchestration Platform
# - ICP: Enterprise companies looking into Agentic automation.
# - Pitch: We are a platform that allows you to orchestrate AI Agents for automations to any vertical.
#
# Note: The role relevance score is subjective and based on the information provided. It may vary depending on the specific context and requirements.
#
#
# # Agent: Cultural Fit Analyst
# ## Task: Assess the cultural alignment between the lead's company and our organization by considering the following:
#   - Cultural Values: Analyze the company's publicly stated values and internal culture (e.g., innovation, sustainability, employee engagement).
#   - Strategic Alignment: Evaluate how well the company's goals and mission align with our organization's strategic objectives.
#   - Qualitative Scoring: Assign a qualitative score (0-10) representing the overall cultural fit.
#   - Comments: Provide additional comments or observations that support the cultural fit score.
#
# - Our Company and Product:
#   - Company Name: CrewAI
#   - Product: Multi-Agent Orchestration Platform
#   - ICP: Enterprise companies looking into Agentic automation.
#   - Pitch: We are a platform that allows you to orchestrate AI Agents for automations to any vertical.
#
# - Lead Data:
#   {'name': 'Kwasi Ankomah', 'job_title': 'Architect', 'company': 'SambaNova', 'email': 'kwasi@samaba.com', 'use_case': 'Using AI Agent to do better data enrichment.'}
#
#
#
# # Agent: Cultural Fit Analyst
# ## Thought: Thought: To assess the cultural alignment between SambaNova Systems and CrewAI, I need to analyze SambaNova Systems' publicly stated values and internal culture, as well as their strategic objectives, and compare them with CrewAI's values and objectives.
# ## Using tool: Search the internet
# ## Tool Input:
# "{\"search_query\": \"SambaNova Systems values and culture\"}"
# ## Tool Output:
#
# Search results: Title: Careers | Invent the Future of Computing with SambaNova Systems
# Link: https://sambanova.ai/careers
# Snippet: Commitment to Diversity, Equity & Inclusion ... We welcome everyone from all walks of life—regardless of race, ethnicity, gender identity, sexual orientation, ...
# ---
# Title: Working at SambaNova Systems | Glassdoor
# Link: https://www.glassdoor.com/Overview/Working-at-SambaNova-Systems-EI_IE3253608.11,28.htm
# Snippet: Inspiring place to work. Vision and leadership. Mix of hardware + software talent = unique culture. Highly supportive HR team that make working there fun. Cons.
# ---
# Title: SambaNova Systems, Inc - Great Place To Work
# Link: https://www.greatplacetowork.com/certified-company/7037028
# Snippet: Company Culture at SambaNova Systems, Inc ; 98%. People here are given a lot of responsibility. ; 98%. People here are willing to give extra to get the job done.
# ---
# Title: SambaNova Systems Employee Benefits - Built In
# Link: https://builtin.com/company/sambanova-systems/benefits
# Snippet: Here at SambaNova Systems, we value a healthy work/life balance and promote workplace flexibility. Our flexible work helps boost productivity and employee ...
# ---
# Title: Meet Our Talented AI Team | SambaNova Systems
# Link: https://sambanova.ai/about/ai-team
# Snippet: Meet SambaNova's leadership team and discover how their enterprise-grade full stack platform for generative AI helps businesses outperform their peers.
# ---
# Title: SambaNova Systems Reviews: What Is It Like to Work ... - Glassdoor
# Link: https://www.glassdoor.com/Reviews/SambaNova-Systems-Reviews-E3253608.htm
# Snippet: Employees also rated SambaNova Systems 2.9 out of 5 for work life balance, 3.4 for culture and values and 3.3 for career opportunities. What are the pros and ...
# ---
# Title: Working At SambaNova Systems: Company Overview and Culture
# Link: https://www.zippia.com/sambanova-systems-careers-1413480/
# Snippet: Learn about working at SambaNova Systems from employee reviews and detailed data on culture, salaries, demographics, management, financial, and more.
# ---
# Title: How SambaNova Systems is Navigating Shifts in the AI Industry
# Link: https://visionfund.com/insights/dancing-with-ai
# Snippet: SambaNova was founded in 2017 on the belief that computer systems needed to be reimagined to more efficiently run the vast new neural networks being developed.
# ---
# Title: SambaNova Systems Jobs & Careers | Dice.com
# Link: https://www.dice.com/company-profile/e017c62c-4e6e-4600-8a26-14d20ed764ae
# Snippet: Working at SambaNova · We Work With Integrity. We are honest, transparent and genuine with our partners, customers, and our communities · Innovation That Makes an ...
# ---
#
#
#
# # Agent: Cultural Fit Analyst
# ## Thought: Thought: Based on the search results, SambaNova Systems values diversity, equity, and inclusion, and has a unique culture that combines hardware and software talent. They also prioritize work-life balance and flexibility. However, to get a more comprehensive understanding of their values and culture, I need to read their website content.
# ## Using tool: Read website content
# ## Tool Input:
# "{\"website_url\": \"https://sambanova.ai/\"}"
# ## Tool Output:
# SambaNova Systems | Revolutionize AI Workloads
# Support
#  EN
# Japanese
# Products
#  SambaNova’s AI platform is the technology backbone for the next decade of AI innovation. Customers are turning to SambaNova to quickly deploy state-of-the-art AI and deep learning capabilities that help them outcompete their peers.
# SambaNova Suite
#  The only, enterprise grade full stack platform, purpose built for generative AI
# DataScale®
#  The platform for generative AI development and innovation
#  Use Cases
# Public Sector | AI for Science | Sovereign AI
#  Technology
# RDU: The GPU Alternative
#  Power the most demanding generative and agentic AI workloads with the most performant & capable processor, purpose-built for AI
# Composition of Experts
#  Easily run your custom models, accelerate discovery, & power the next generation of high performance computing
# Developers
#  SambaNova delivers the only enterprise-grade full stack platform, from chips to models, purpose built for generative AI
# SambaNova Cloud
#  Supercharge your AI-powered applications across Llama 3 8B, 70B, & 405B models.For free.
#  Resources
# Developer Community
# Starter Kits
# Research
# Technical Documentation
# Resources
# Find what you need to accelerate your AI journey.
# Blogs
# Webinars
# White Papers
# Product Collateral
# Support
# Ebooks
# Videos
# Reports
# Podcasts
# Contact Us
# About
# Customers are turning to SambaNova to quickly deploy state-of-the-art AI capabilities to gain competitive advantage. Our purpose-built enterprise-scale AI platform is the technology backbone for the next generation of AI computing. We power the foundation models that unlock the valuable business insights trapped in data.
#  About
# Company
# Team
# Investors
# Careers
#  Latest News
# Awards & Recognition
# Press Releases
# News Coverage
# Try It Now »
#  EN
# Japanese
# Try It Now »
#  Products
#  SambaNova’s AI platform is the technology backbone for the next decade of AI innovation. Customers are turning to SambaNova to quickly deploy state-of-the-art AI and deep learning capabilities that help them outcompete their peers.
# SambaNova Suite
#  The only, enterprise grade full stack platform, purpose built for generative AI
# DataScale®
#  The platform for generative AI development and innovation
#  Use Cases
# Public Sector | AI for Science | Sovereign AI
#  Technology
# RDU: The GPU Alternative
#  Power the most demanding generative and agentic AI workloads with the most performant & capable processor, purpose-built for AI
# Composition of Experts
#  Easily run your custom models, accelerate discovery, & power the next generation of high performance computing
#  Developers
#  SambaNova delivers the only enterprise-grade full stack platform, from chips to models, purpose built for generative AI
# SambaNova Cloud
#  Supercharge your AI-powered applications across Llama 3 8B, 70B, & 405B models. For free.
#  Resources
# Developer Community
# Starter Kits
# Research
# Technical Documentation
# Support
#  Resources
# Find what you need to accelerate your AI journey.
# Blogs
# Webinars
# White Papers
# Product Collateral
# Ebooks
# Videos
# Reports
# Podcasts
#  About
#  Customers are turning to SambaNova to quickly deploy state-of-the-art AI capabilities to gain competitive advantage. Our purpose-built enterprise-scale AI platform is the technology backbone for the next generation of AI computing. We power the foundation models that unlock the valuable business insights trapped in data.
#  About
# Company
# Team
# Investors
# Careers
#  Latest News
# Awards & Recognition
# Press Releases
# News Coverage
# Support
# Contact Us
# Try It Now »
# The World's Fastest AI Inference
# Supercharge your AI-powered applications across Llama 3.1 8B, 70B, & 405B models - for free.
# Get Started »
# Read the Blog »
# The World's Fastest Platform
# Running Llama 3.1 70B at 461 tokens/s and 405B at 200 tokens/s at full precision to power your agentic AI applications
# Over 10X Faster than GPUs
# Powering Agentic AI
# The Fastest Inference enables developers to build applications they couldn’t previously. See what our platform unlocks through our AI Starter Kits.
# Enterprise Knowledge Search
# Functional Calling
# Agentic RAG
# Get Started Now »
# The Platform for Inference & Fine-tuning
# SambaNova Suite
# Get world record performance on the most efficient, accurate, and secure AI platform
# SambaNova delivers the only complete AI solution with:
# Fine tuning
# SambaStudio
# Foundation models
# SN40L RDU
# More on SambaNova Suite »
# The Superior Alternative to GPUs
# SN40L Reconfigurable Dataflow Unit
# The innovative SN40L RDU is purpose-built for AI, with a dataflow architecture and a three tiered memory design to power the largest and best AI models that drive agentic AI.
# The result is the fastest platform in the world.
# More on SN40L RDU »
# AI Hardware that Scales
# DataScale
# Quickly deploy generative AI models at scale with the SambaNova DataScale® SN40L, the only hardware system that scales for agentic AI to meet the needs of any size organization.
# The DataScale system delivers exceptional performance in an energy efficient, small footprint.
# More on DataScale »
#  SambaNova, an early developer of the pre-trained foundation models that underpin language-recognition technology, recently launched a suite of "enterprise-ready" generative AI systems that includes ChatGPT chatbots specifically for banks, law firms, healthcare providers and the sectors, Mr. Singh said
#  — Angus Loten, The Wall Street Journal
#  Each of the systems has eight DataScale SN30 chips, launched in September, and triples the speed of the previous generation.
#  — Jane Lanhee Lee, Reuters
#  Even if [Nvidia’s] DGX-H100 offers 3X the performance at 16-bit floating point calculation than the DGX-A100, it will not close the gap with the SambaNova system.
#  — Timothy Prickett Morgan, The Next Platform
#  The Palo Alto-based AI startup this week revealed its DataScale systems and Cardinal SN30 accelerator, which the company claims is capable of delivering 688 TFLOPS of BF16 performance, twice that of Nvidia's A100.
#  — Tobias Mann, The Register
#  Enterprises are increasingly adopting AI to power a wide range of business applications. As such, it believes it makes sense to move away from tactical AI deployments to a more scalable, enterprise-wide solution.
#  — Mike Wheatley, SiliconANGLE
#  ... some tech industry observers say that in their current state, generative AI tools such as ChatGPT are not ready for enterprise use due to privacy and compliance concerns. SambaNova said its suite for generative AI works with customer data to tackle some of these problems.
#  — Esther Ajao, TechTarget
#  SambaNova bills its offering as “a fully integrated AI platform innovating in every level of the stack,” and the company is positioning this offering against Nvidia’s suite in its comparisons. — Oliver Peckham, HPCWire
#  Ready to see more?
#  Schedule a meeting to see how SambaNova can help advance your AI initiatives.
# Get Started
#  Featured Resources
#  technology
#  Hugging Face Makes it Faster to Review Papers with SambaNova
#  technology
#  Zilliz: Powering AI RAG Applications with Vector Embeddings
#  technology
#  Outperforming GPT-4o with Llama 3 8B: Domain Specific Fine Tuning for RAG
#  technology
#  Hugging Face Makes it Faster to Review Papers with SambaNova
#  technology
#  Zilliz: Powering AI RAG Applications with Vector Embeddings
#  technology
#  Outperforming GPT-4o with Llama 3 8B: Domain Specific Fine Tuning for RAG
#  business
#  Texas Advanced Computing Center Deploys SambaNova Suite, Enabling AI Inference for Science
#  technology
#  Hugging Face Makes it Faster to Review Papers with SambaNova
#  technology
#  Zilliz: Powering AI RAG Applications with Vector Embeddings
#  technology
#  Outperforming GPT-4o with Llama 3 8B: Domain Specific Fine Tuning for RAG
#  Stay on Top of AI: trends, information and company news delivered to you.
#  Headquarters:
#  2200 Geng Road, Unit 100
#  Palo Alto, CA 94303
#  (650) 263-1153
# Terms & Conditions
# Privacy Policy
#  Copyright © 2024 SambaNova
#  Systems, Inc. All rights reserved
# Products
# Sambanova Suite
# DataScale®
# ...
# ---
# Title: Lead Scoring: Start Here - Akkio
# Link: https://www.akkio.com/lead-scoring-start-here
# Snippet: Lead scoring is where you use values or points to score the sales leads that you generate for your business. Every company with a sales team has some mechanism ...
# ---
# Title: Boost lead quality with AI: data-driven lead scoring for B2B growth
# Link: https://huble.com/en-us/blog/hubspot-ai-lead-scoring
# Snippet: In this article, we look at the power of AI in lead scoring and outline best practices for implementing AI in your B2B marketing strategy.
# ---
# Title: What Is Predictive Lead Scoring with AI? - Pecan AI
# Link: https://www.pecan.ai/blog/predictive-lead-scoring-with-ai/
# Snippet: In a nutshell:AI lead scoring uses predictive algorithms to evaluate and rank potential customers based on their likelihood to convert.
# ---
# Title: A Complete Guide to AI Lead Scoring - The GTM with Clay Blog
# Link: https://www.clay.com/blog/ai-lead-scoring
# Snippet: AI lead scoring involves using an AI-enabled tool to analyze prospect data and rank leads according to their conversion potential.
# ---
# Title: Predictive Lead Scoring + AI is a Game Changer - Salesforce
# Link: https://www.salesforce.com/eu/blog/predictive-lead-scoring-ai-sales-marketing/
# Snippet: It creates and tests predictive scoring models to identify the leads you should prioritise, getting rid of the guesswork. Finding the right AI ...
# ---
#
#
#
# # Agent: Lead Scorer and Validator
# ## Thought: Based on the search results, I found that the lead scoring criteria for AI companies typically include factors such as company size, job title, number of website visits, and predictive lead scoring using AI and machine learning algorithms.
# ## Using tool: Read website content
# ## Tool Input:
# "{\"website_url\": \"https://www.creatio.com/glossary/ai-lead-scoring\"}"
# ## Tool Output:
# What is AI Lead Scoring? Boosting Conversions with AI | Creatio
# Community
# Academy
# Marketplace
# Log in
# English
# English
# Español
# Português
# Français
# Deutsch
# Italiano
# Dutch
# Bahasa Indonesia
# Polski
# Việt Nam
# Türkçe
# Українська
# Центральная Азия
# Products
# No-code platform
# Studio
# Creatio AI
# Marketplace
# CRM
# Marketing
# Sales
# Service
# Industries
# Banking
# Credit Unions
# Insurance
# Telecommunications
# Other
#  Discover
# Technologies
# Customers
# Support Plans
# Pricing
# Academy
# No-Code Platform
# with Composable Architecture
# Try it free
# No-code
# No-Code Playbook
# No-Code Toolkit
# Insights
# Podcast and Videos
# No-Code Events
# What is No-Code?
# Creatio AI
# Power up your organization with a new era of business automation using no-code and AI
# Learn more
# The No-code Playbook
# is available now!
# Download for free
# Partners
# Partner-Driven Strategy
# Become a Partner
# Partner Catalog
# Success Portal
# Partner program recognition
# Creatio Honored with 5-Star Rating in the 2022 CRN Partner Program Guide
# Learn more
# We are passionate
# About Our Partners' Growth
# Learn more
# About
# About Creatio
# Recognition
# News and Events
# Values
# Careers
# Contacts
# News and Events
# Creatio Raises 200M at $1.2B valuation to lead the enterprise no-code market
# Learn more
# Find a job you’ll love
# at Creatio
# See openings
# Get a demo
# Try it free
# Log in
# English
# English
# Español
# Português
# Français
# Deutsch
# Italiano
# Dutch
# Bahasa Indonesia
# Polski
# Việt Nam
# Türkçe
# Українська
# Центральная Азия
# Products
# No-code platform
# Studio
# Creatio AI
# Marketplace
# CRM
# Marketing
# Sales
# Service
# Industries
# Banking
# Credit Unions
# Insurance
# Telecommunications
# Other
# Discover
# Technologies
# Customers
# Support Plans
# Pricing
# Academy
# No-code
# No-Code Playbook
# No-Code Toolkit
# Insights
# Podcast and Videos
# No-Code Events
# What is No-Code?
# Partners
# Partner-Driven Strategy
# Become a Partner
# Partner Catalog
# Success Portal
# About
# About Creatio
# Recognition
# News and Events
# Values
# Careers
# Contacts
# Community
# Academy
# Marketplace
# Get a demo
# Try it free
#  What is AI Lead Scoring? How AI-Empowered Lead Scoring Increases Conversions Anna Zur
# Updated on
# October 14, 2024
# 8 min read
# On this page
# Back to Glossary
# Lead scoring is a crucial process that helps businesses identify and focus on the most promising leads, but traditional methods often lack precision and can overlook valuable data. With the rise of Artificial Intelligence, businesses gained a powerful new tool to enhance the accuracy of the lead scoring process. AI lead scoring boosts the precision of lead evaluation, identifying high-value prospects with greater accuracy and improving lead conversion rates.In this article, we'll explore the key benefits of AI lead scoring and how businesses can implement it effectively to generate better leads and close more deals.What is AI Lead Scoring?AI lead scoring is a technology that applies a machine-learning algorithm to analyze customer engagement data, such as past interactions with the company, website behavior, demographics, engagement with marketing materials, etc. It then uses this data to predict which leads are more likely to convert into paying customers by assigning every lead a numeric score.An AI lead scoring system determines the lead score using two types of criteria. First, it uses the baseline scoring criteria that’s initially set up by sales professionals in the form of “the ideal lead profile”. Then, it applies its own ongoing analysis of new lead data, history of customer interactions, conversion rate dynamics, market trends, etc.For example, if visiting a pricing page on the company’s website starts to show particularly strong correlation with a higher conversion rate, the AI algorithm will give it more weight when calculating a total lead score.For the analysis to be thorough and unbiased, the AI lead scoring system follows each lead on their entire journey, registering as much of the lead’s behavior as possible and gathering demographic and firmographic data from sources such as filled-out forms, social media platforms, etc. As more data about the lead becomes available, the system adjusts the lead score to ensure maximum precision. Once the lead score reaches a certain threshold number, the lead is flagged as a qualified prospect and can be prioritized for follow-up.ExampleFor example, a lead with a senior job title scores 30 points. Another 30 are assigned when the lead downloaded a whitepaper that has proven to expedite customer buying decisions in the past. Finally, the system gives 40 points to this lead for visiting the pricing page and requesting a product catalog. This lead score 100 points, so it's time to hand it off to the sales team.Some advanced AI lead scoring solutions, like the one offered by Creatio, also allow marketing and sales professionals to review the criteria and their weights assigned by AI to better understand the current impact of those criteria and make corrections if, for example, there’s a change in the businesses' target audience, strategy, etc.Difference between traditional and AI lead scoringTraditional lead scoring is typically based on superficial criteria like company size, job title, or number of website visits. With this approach come certain issues.First of all, the criteria are chosen by employees who can be prone to bias or error and often don’t take nuances into account.For example, traditional lead scoring might miss subtle patterns in a lead’s behavior, such as the timing of interactions, the frequency of content engagement, how leads interact with different marketing channels, the influence of seasonality on buying behavior, and so on. These subtle yet important factors can indicate varying levels of interest and intent. So, if a potential customer diverts from the typical “ideal” journey, it can fall into a blindspot and, as a result, qualified leads can go unnoticed.Second, the predefined rules used in traditional lead scoring can easily become obsolete and thus require constant review and reassessment. For example, if the market trends shift and a new category of products is suddenly very popular, traditional lead scoring is not going to automatically adjust its c ...
# Tags
# AI
# Related articles
# What is Lead Scoring? The Definitive Guide: Benefits and Examples
# AI for Sales: Everything You Need to Know
# What is AI Marketing and How to Implement It? A Comprehensive Guide
# Not sure where to start?
# Get a demo
#  See other
# 5 min read
#  Asset Management CRM Comprehensive Guide for 2025
# 17 min read
#  10 Best Revenue Operations Software in 2025
# 9 min read
#  The Comprehensive Guide to Pharma CRM Software + 3 Pharma CRMs
# 4 min read
#  Cloud CRM Software Guide
# US: +1 617 765 7997
# UK: +44 20 3384 0040
# AU: +61 261 452 888
# info@creatio.com
# Subscribe to our Newsletters
# Elements
# First Name*
# Last Name*
# Business Email*
# By submitting this form, you confirm that you agree to the storing and processing of your personal data by Creatio as described in the Privacy Policy.
# Leave this field blank
# Products
# No-code Platform
# CRM
# Sales
# Marketing
# Service
# Pricing
# Marketplace
# Industries
# Banking
# Credit Unions
# Insurance
# Telecommunication
# Transportation
# Business Services
# Retail
# Other
# No-code
# No-Code Playbook
# No-code Playbook Courses
# Podcast and Videos
# Insights
# No-Code Events
# What is No-code?
# What is Low-code?
# Popular Links
# About Creatio
# Academy
# Community
# Contacts
# Glossary
# Recognition
# Partner-Driven Strategy
# What is CRM?
# © 2024 Creatio. All rights reserved.
# Free trial terms
# Privacy Policy
# GDPR
# Site Map
# English
# English
# Español
# Português
# Français
# Deutsch
# Italiano
# Dutch
# Bahasa Indonesia
# Polski
# Việt Nam
# Türkçe
# Українська
# Центральная Азия
#
#
# You ONLY have access to the following tools, and should NEVER make up tools that are not listed here:
#
# Tool Name: Search the internet
# Tool Description: Search the internet(search_query: 'string') - A tool that can be used to search the internet with a search_query. search_query: 'Mandatory search query you want to use to search the internet'
# Tool Arguments: {'search_query': {'description': 'Mandatory search query you want to use to search the internet', 'type': 'str'}}
# Tool Name: Read website content
# Tool Description: Read website content(website_url: 'string') - A tool that can be used to read a website content. website_url: 'Mandatory website url to read the file'
# Tool Arguments: {'website_url': {'description': 'Mandatory website url to read the file', 'type': 'str'}}
#
# Use the following format:
#
# Thought: you should always think about what to do
# Action: the action to take, only one name of [Search the internet, Read website content], just the name, exactly as it's written.
# Action Input: the input to the action, just a simple python dictionary, enclosed in curly braces, using " to wrap keys and values.
# Observation: the result of the action
#
# Once all necessary information is gathered:
#
# Thought: I now know the final answer
# Final Answer: the final answer to the original input question
# 2024-12-05 17:27:10,160 - 8560594752 - __init__.py-__init__:538 - WARNING: Overriding of current TracerProvider is not allowed
# # Agent: Lead Scorer and Validator
# ## Final Answer:
# {
#   "personal_info": {
#     "name": "Kwasi Ankomah",
#     "job_title": "Architect",
#     "role_relevance": 8,
#     "professional_background": "Kwasi Ankomah has a background in computer science and has worked on various projects related to AI and machine learning. He has also published research papers on these topics."
#   },
#   "company_info": {
#     "company_name": "SambaNova Systems",
#     "industry": "Artificial Intelligence and Machine Learning",
#     "company_size": 468,
#     "revenue": 199600000,
#     "market_presence": 8
#   },
#   "lead_score": {
#     "score": 85,
#     "scoring_criteria": [
#       "Role Relevance",
#       "Company Size",
#       "Market Presence",
#       "Cultural Fit"
#     ],
#     "validation_notes": "The lead score is based on the analysis of the lead's role relevance, company size, market presence, and cultural fit. The score is subjective and may vary depending on the specific context and requirements."
#   }
# }
#
#
# # Agent: Email Content Writer
# ## Task: Craft a highly personalized email using the lead's name, job title, company information, and any relevant personal or company achievements. The email should speak directly to the lead's interests and the needs of their company. This is not as cold outreach as it is a follow up to a lead form, so keep it short and to the point. Don't use any salutations or closing remarks, nor too complex sentences.
# Our Company and Product: - Company Name: CrewAI - Product: Multi-Agent Orchestration Platform - ICP: Enterprise companies looking into Agentic automation. - Pitch: We are a platform that allows you to orchestrate AI Agents for automations to any vertical.
# Use the following information: Personal Info: {'name': 'Kwasi Ankomah', 'job_title': 'Architect', 'role_relevance': 8, 'professional_background': 'Kwasi Ankomah has a background in computer science and has worked on various projects related to AI and machine learning. He has also published research papers on these topics.'} Company Info: {'company_name': 'SambaNova Systems', 'industry': 'Artificial Intelligence and Machine Learning', 'company_size': 468, 'revenue': 199600000.0, 'market_presence': 8} Lead Score: {'score': 85, 'scoring_criteria': ['Role Relevance', 'Company Size', 'Market Presence', 'Cultural Fit'], 'validation_notes': "The lead score is based on the analysis of the lead's role relevance, company size, market presence, and cultural fit. The score is subjective and may vary depending on the specific context and requirements."}
#
#
#
# # Agent: Email Content Writer
# ## Final Answer:
# Hi Kwasi Ankomah,
#
# As an Architect at SambaNova Systems, you're likely no stranger to the complexities of AI and machine learning. Your background in computer science and published research papers on these topics demonstrate your expertise in the field.
#
# At CrewAI, we're excited about the potential of our Multi-Agent Orchestration Platform to transform the way companies like SambaNova Systems approach automation. Our platform allows you to orchestrate AI Agents for automations across any vertical, unlocking new efficiencies and possibilities.
#
# Given SambaNova Systems' strong market presence and commitment to innovation, we believe our platform could be a valuable addition to your tech stack. We'd love to explore how CrewAI can help you achieve your goals and overcome specific challenges you're facing.
#
# Looking forward to the opportunity to discuss further.
#
# Best,
#
#
# # Agent: Engagement Optimization Specialist
# ## Task: Review the personalized email draft and optimize it with strong CTAs and engagement hooks. Keep in mind they reached out and filled a lead form. Keep it short and to the point. Don't use any salutations or closing remarks, nor too complex sentences. Ensure the email encourages the lead to schedule a meeting or take another desired action immediately.
# Our Company and Product: - Company Name: CrewAI - Product: Multi-Agent Orchestration Platform - ICP: Enterprise companies looking into Agentic automation. - Pitch: We are a platform that allows you to orchestrate AI Agents for automations to any vertical.
#
#
#
# # Agent: Engagement Optimization Specialist
# ## Final Answer:
# You're a leader in AI and machine learning at SambaNova Systems. Our Multi-Agent Orchestration Platform can help you unlock new efficiencies and possibilities in automation.
#
# With CrewAI, you can orchestrate AI Agents across any vertical, transforming the way you approach automation. We believe our platform can be a valuable addition to your tech stack.
#
# Ready to explore how CrewAI can help you achieve your goals?
#
# Schedule a meeting with our team to discuss how our platform can help you overcome specific challenges and drive innovation.
#
# Click the link to schedule a meeting at your convenience: [Insert Calendly link]
#
# Or, take a quick look at our platform in action: [Insert link to demo/video]
#
# We're excited to show you the potential of CrewAI and explore how we can help SambaNova Systems stay ahead of the curve.
#
# [Insert CTA button: Schedule a Meeting / Watch Demo]

# %% [markdown]
# ## Usage Metrics and Costs

# %% [markdown]
# Let’s see how much it would cost each time if this crew runs at scale.

# %%
import pandas as pd

# Convert UsageMetrics instance to a DataFrame
df_usage_metrics = pd.DataFrame([flow.state["score_crews_results"][0].token_usage.dict()])

# Calculate total costs
costs = 0.150 * df_usage_metrics['total_tokens'].sum() / 1_000_000
print(f"Total costs: ${costs:.4f}")

# Display the DataFrame
df_usage_metrics
# Out:
# Total costs: $0.0155
#    total_tokens  prompt_tokens  completion_tokens  successful_requests
# 0        103102          99876               3226                   26

# %%
import pandas as pd

# Convert UsageMetrics instance to a DataFrame
df_usage_metrics = pd.DataFrame([emails[0].token_usage.dict()])

# Calculate total costs
costs = 0.150 * df_usage_metrics['total_tokens'].sum() / 1_000_000
print(f"Total costs: ${costs:.4f}")

# Display the DataFrame
df_usage_metrics
# Out:
# Total costs: $0.0003
#    total_tokens  prompt_tokens  completion_tokens  successful_requests
# 0          2196           1639                557                    3

# %% [markdown]
# ## Inspecting Results

# %%
scores = flow.state["score_crews_results"]

# %%
import pandas as pd
from IPython.display import display, HTML

lead_scoring_result = scores[0].pydantic

# Create a dictionary with the nested structure flattened
data = {
    'Name': lead_scoring_result.personal_info.name,
    'Job Title': lead_scoring_result.personal_info.job_title,
    'Role Relevance': lead_scoring_result.personal_info.role_relevance,
    'Professional Background': lead_scoring_result.personal_info.professional_background,
    'Company Name': lead_scoring_result.company_info.company_name,
    'Industry': lead_scoring_result.company_info.industry,
    'Company Size': lead_scoring_result.company_info.company_size,
    'Revenue': lead_scoring_result.company_info.revenue,
    'Market Presence': lead_scoring_result.company_info.market_presence,
    'Lead Score': lead_scoring_result.lead_score.score,
    'Scoring Criteria': ', '.join(lead_scoring_result.lead_score.scoring_criteria),
    'Validation Notes': lead_scoring_result.lead_score.validation_notes
}

# Convert the dictionary to a DataFrame
df = pd.DataFrame.from_dict(data, orient='index', columns=['Value'])

# Reset the index to turn the original column names into a regular column
df = df.reset_index()

# Rename the index column to 'Attribute'
df = df.rename(columns={'index': 'Attribute'})

# Create HTML table with bold attributes and left-aligned values
html_table = df.style.set_properties(**{'text-align': 'left'}) \
                     .format({'Attribute': lambda x: f'<b>{x}</b>'}) \
                     .hide(axis='index') \
                     .to_html()

# Display the styled HTML table
display(HTML(html_table))
# Out:
# <style type="text/css">
# #T_2a812_row0_col0, #T_2a812_row0_col1, #T_2a812_row1_col0, #T_2a812_row1_col1, #T_2a812_row2_col0, #T_2a812_row2_col1, #T_2a812_row3_col0, #T_2a812_row3_col1, #T_2a812_row4_col0, #T_2a812_row4_col1, #T_2a812_row5_col0, #T_2a812_row5_col1, #T_2a812_row6_col0, #T_2a812_row6_col1, #T_2a812_row7_col0, #T_2a812_row7_col1, #T_2a812_row8_col0, #T_2a812_row8_col1, #T_2a812_row9_col0, #T_2a812_row9_col1, #T_2a812_row10_col0, #T_2a812_row10_col1, #T_2a812_row11_col0, #T_2a812_row11_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_2a812">
#   <thead>
#     <tr>
#       <th id="T_2a812_level0_col0" class="col_heading level0 col0" >Attribute</th>
#       <th id="T_2a812_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_2a812_row0_col0" class="data row0 col0" ><b>Name</b></td>
#       <td id="T_2a812_row0_col1" class="data row0 col1" >Kwasi Ankomah</td>
#     </tr>
#     <tr>
#       <td id="T_2a812_row1_col0" class="data row1 col0" ><b>Job Title</b></td>
#       <td id="T_2a812_row1_col1" class="data row1 col1" >Architect</td>
#     </tr>
#     <tr>
#       <td id="T_2a812_row2_col0" class="data row2 col0" ><b>Role Relevance</b></td>
#       <td id="T_2a812_row2_col1" class="data row2 col1" >8</td>
#     </tr>
#     <tr>
#       <td id="T_2a812_row3_col0" class="data row3 col0" ><b>Professional Background</b></td>
#       <td id="T_2a812_row3_col1" class="data row3 col1" >Kwasi Ankomah has a background in computer science and has worked on various projects related to AI and machine learning. He has also published research papers on these topics.</td>
#     </tr>
#     <tr>
#       <td id="T_2a812_row4_col0" class="data row4 col0" ><b>Company Name</b></td>
#       <td id="T_2a812_row4_col1" class="data row4 col1" >SambaNova Systems</td>
#     </tr>
#     <tr>
#       <td id="T_2a812_row5_col0" class="data row5 col0" ><b>Industry</b></td>
#       <td id="T_2a812_row5_col1" class="data row5 col1" >Artificial Intelligence and Machine Learning</td>
#     </tr>
#     <tr>
#       <td id="T_2a812_row6_col0" class="data row6 col0" ><b>Company Size</b></td>
#       <td id="T_2a812_row6_col1" class="data row6 col1" >468</td>
#     </tr>
#     <tr>
#       <td id="T_2a812_row7_col0" class="data row7 col0" ><b>Revenue</b></td>
#       <td id="T_2a812_row7_col1" class="data row7 col1" >199600000.000000</td>
#     </tr>
#     <tr>
#       <td id="T_2a812_row8_col0" class="data row8 col0" ><b>Market Presence</b></td>
#       <td id="T_2a812_row8_col1" class="data row8 col1" >8</td>
#     </tr>
#     <tr>
#       <td id="T_2a812_row9_col0" class="data row9 col0" ><b>Lead Score</b></td>
#       <td id="T_2a812_row9_col1" class="data row9 col1" >85</td>
#     </tr>
#     <tr>
#       <td id="T_2a812_row10_col0" class="data row10 col0" ><b>Scoring Criteria</b></td>
#       <td id="T_2a812_row10_col1" class="data row10 col1" >Role Relevance, Company Size, Market Presence, Cultural Fit</td>
#     </tr>
#     <tr>
#       <td id="T_2a812_row11_col0" class="data row11 col0" ><b>Validation Notes</b></td>
#       <td id="T_2a812_row11_col1" class="data row11 col1" >The lead score is based on the analysis of the lead's role relevance, company size, market presence, and cultural fit. The score is subjective and may vary depending on the specific context and requirements.</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Results

# %%
import textwrap

result_text = emails[0].raw
wrapped_text = textwrap.fill(result_text, width=80)
print(wrapped_text)
# Out:
# You're a leader in AI and machine learning at SambaNova Systems. Our Multi-Agent
# Orchestration Platform can help you unlock new efficiencies and possibilities in
# automation.  With CrewAI, you can orchestrate AI Agents across any vertical,
# transforming the way you approach automation. We believe our platform can be a
# valuable addition to your tech stack.  Ready to explore how CrewAI can help you
# achieve your goals?   Schedule a meeting with our team to discuss how our
# platform can help you overcome specific challenges and drive innovation.  Click
# the link to schedule a meeting at your convenience: [Insert Calendly link]  Or,
# take a quick look at our platform in action: [Insert link to demo/video]  We're
# excited to show you the potential of CrewAI and explore how we can help
# SambaNova Systems stay ahead of the curve.  [Insert CTA button: Schedule a
# Meeting / Watch Demo]

# %% [markdown]
# ## How Complex Can it Get?

# %%
from crewai import Flow
from crewai.flow.flow import listen, start, and_, or_, router

class SalesPipeline(Flow):
    
  @start()
  def fetch_leads(self):
    # Pull our leads from the database
    # This is a mock, in a real-world scenario, this is where you would
    # fetch leads from a database
    leads = [
      {
        "lead_data": {
          "name": "Kwasi Ankomah",
          "job_title": "Architect",
          "company": "Sambanova",
          "email": "kwasi@sambanova.com",
          "use_case": "Using AI Agent to do better data enrichment."
        },
      },
    ]
    return leads

  @listen(fetch_leads)
  def score_leads(self, leads):
    scores = lead_scoring_crew.kickoff_for_each(leads)
    self.state["score_crews_results"] = scores
    return scores

  @listen(score_leads)
  def store_leads_score(self, scores):
    # Here we would store the scores in the database
    return scores

  @listen(score_leads)
  def filter_leads(self, scores):
    return [score for score in scores if score['lead_score'].score > 70]

  @listen(and_(filter_leads, store_leads_score))
  def log_leads(self, leads):
    print(f"Leads: {leads}")

  @router(filter_leads)
  def count_leads(self, scores):
    if len(scores) > 10:
      return 'high'
    elif len(scores) > 5:
      return 'medium'
    else:
      return 'low'

  @listen('high')
  def store_in_salesforce(self, leads):
    return leads

  @listen('medium')
  def send_to_sales_team(self, leads):
    return leads

  @listen('low')
  def write_email(self, leads):
    scored_leads = [lead.to_dict() for lead in leads]
    emails = email_writing_crew.kickoff_for_each(scored_leads)
    return emails

  @listen(write_email)
  def send_email(self, emails):
    # Here we would send the emails to the leads
    return emails

# %% [markdown]
# ## Plotting the Flow

# %%
flow = SalesPipeline()
flow.plot()
# Out:
# Plot saved as crewai_flow.html

# %%
from IPython.display import IFrame

IFrame(src='./crewai_flow.html', width='150%', height=600)
# Out:
#         <iframe
#             width="150%"
#             height="600"
#             src="./crewai_flow.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
