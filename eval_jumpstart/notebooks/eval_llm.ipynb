# %%
from dotenv import load_dotenv
import json
import sys
import os

current_dir = os.getcwd()
kit_dir = os.path.abspath(os.path.join(current_dir, '..'))
repo_dir = os.path.abspath(os.path.join(kit_dir, '..'))
sys.path.append(kit_dir)
sys.path.append(repo_dir)

load_dotenv(os.path.join(repo_dir, '.env'), override=True)

from utils.eval.llm import CorrectnessLLMJudge, WeaveChatModel
from utils.eval.evaluator import BaseWeaveEvaluator
import weave

# %%
judge = CorrectnessLLMJudge(
            model_type="sncloud",
            model_name="Meta-Llama-3.1-405B-Instruct", 
            max_tokens=1024, 
            temperature=0
        )

# %%
test_model = WeaveChatModel(
            model_type="sncloud",
            model_name="Meta-Llama-3.1-405B-Instruct", 
            max_tokens=1024, 
            temperature=0
        )

# %%
example = {
    "system_message": "You are a general knowledge expert.",
    "query": "What is the significance of the Heisenberg Uncertainty Principle in quantum mechanics?",
    "expected_answer": "The Heisenberg Uncertainty Principle states that it is impossible to simultaneously know both the exact position and momentum of a particle, highlighting fundamental limits to measurement in quantum mechanics."
}

# %%
result = await test_model.predict(query=example["query"], system_message=example["system_message"])
score = await judge.score(query=example["query"], model_output=result, expected_answer=example["expected_answer"])

score
# Out:
# {'score': 1}

# %%
weave.init('your-project-name')

# %%
evaluator = BaseWeaveEvaluator()

# %%
await evaluator.evaluate(name="general_knowledge_test", filepath="../data/eval_data.csv")
# Out:
# Evaluated 1 of 10 examples
# Evaluated 2 of 10 examples
# Evaluated 3 of 10 examples
# Evaluated 4 of 10 examples
# Evaluated 5 of 10 examples
# Evaluated 6 of 10 examples
# Evaluated 7 of 10 examples
# Evaluated 8 of 10 examples
# Evaluated 9 of 10 examples
# Evaluated 10 of 10 examples
# Evaluation summary
# {
#     'model_output': {
#         'usage': {
#             'total_tokens': {'mean': 543.4},
#             'completion_tokens_after_first_per_sec': {'mean': 109.96705179702269},
#             'end_time': {'mean': 1729530912.5480137},
#             'time_to_first_token': {'mean': 0.345880913734436},
#             'total_latency': {'mean': 4.671297587993925},
#             'is_last_response': {'true_count': 10, 'true_fraction': 1.0},
#             'completion_tokens_per_sec': {'mean': 103.09967439262009},
#             'prompt_tokens': {'mean': 57.8},
#             'completion_tokens': {'mean': 485.6},
#             'start_time': {'mean': 1729530907.8147464},
#             'acceptance_rate': {'mean': 4.5054421309446715},
#             'completion_tokens_after_first_per_sec_first_ten': {'mean': 111.80357106042568},
#             'total_tokens_per_sec': {'mean': 116.12591543940148}
#         }
#     },
#     'CorrectnessLLMJudge': {'score': {'mean': 0.93}},
#     'model_latency': {'mean': 5.581290602684021}
# }
# Evaluated 1 of 10 examples
# Evaluated 2 of 10 examples
# Evaluated 3 of 10 examples
# Evaluated 4 of 10 examples
# Evaluated 5 of 10 examples
# Evaluated 6 of 10 examples
# Evaluated 7 of 10 examples
# Evaluated 8 of 10 examples
# Evaluated 9 of 10 examples
# Evaluated 10 of 10 examples
# Evaluation summary
# {'CorrectnessLLMJudge': {'score': {'mean': 0.89}}, 'model_latency': {'mean': 6.176282238960266}}
# Evaluated 1 of 10 examples
# Evaluated 2 of 10 examples
# Evaluated 3 of 10 examples
# Evaluated 4 of 10 examples
# Evaluated 5 of 10 examples
# Evaluated 6 of 10 examples
# Evaluated 7 of 10 examples
# Evaluated 8 of 10 examples
# Evaluated 9 of 10 examples
# Evaluated 10 of 10 examples
# Evaluation summary
# {
#     'model_output': {
#         'usage': {
#             'total_tokens': {'mean': 548.3},
#             'completion_tokens_after_first_per_sec': {'mean': 424.34668229291475},
#             'end_time': {'mean': 1729531067.8634434},
#             'time_to_first_token': {'mean': 0.14750292301177978},
#             'total_latency': {'mean': 1.2609183620951676},
#             'is_last_response': {'true_count': 10, 'true_fraction': 1.0},
#             'completion_tokens_per_sec': {'mean': 389.7788562485897},
#             'prompt_tokens': {'mean': 57.8},
#             'completion_tokens': {'mean': 490.5},
#             'start_time': {'mean': 1729531066.5411065},
#             'acceptance_rate': {'mean': 5.092462193771434},
#             'completion_tokens_after_first_per_sec_first_ten': {'mean': 444.5008084321291},
#             'total_tokens_per_sec': {'mean': 438.4876039659656}
#         }
#     },
#     'CorrectnessLLMJudge': {'score': {'mean': 0.9400000000000001}},
#     'model_latency': {'mean': 1.9605809450149536}
# }
# Evaluated 1 of 10 examples
# Evaluated 2 of 10 examples
# Evaluated 3 of 10 examples
# Evaluated 4 of 10 examples
# Evaluated 5 of 10 examples
# Evaluated 6 of 10 examples
# Evaluated 7 of 10 examples
# Evaluated 8 of 10 examples
# Evaluated 9 of 10 examples
# Evaluated 10 of 10 examples
# Evaluation summary
# {
#     'model_output': {
#         'usage': {
#             'total_tokens': {'mean': 584.5},
#             'completion_tokens_after_first_per_sec': {'mean': 1521.8155691420739},
#             'end_time': {'mean': 1729531123.928701},
#             'time_to_first_token': {'mean': 0.029649901390075683},
#             'total_latency': {'mean': 0.374834942817688},
#             'is_last_response': {'true_count': 10, 'true_fraction': 1.0},
#             'completion_tokens_per_sec': {'mean': 1413.8238639254314},
#             'prompt_tokens': {'mean': 57.8},
#             'completion_tokens': {'mean': 526.7},
#             'start_time': {'mean': 1729531123.553866},
#             'acceptance_rate': {'mean': 1.0},
#             'completion_tokens_after_first_per_sec_first_ten': {'mean': 1471.7562138533694},
#             'total_tokens_per_sec': {'mean': 1576.4161387683437}
#         }
#     },
#     'CorrectnessLLMJudge': {'score': {'mean': 0.93}},
#     'model_latency': {'mean': 0.9888641834259033}
# }
