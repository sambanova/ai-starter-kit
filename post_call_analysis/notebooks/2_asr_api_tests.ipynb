# %%
import os
import io
import sys
import time
import shutil

import json
import yaml
import tarfile

import requests

import pandas as pd
from pandas import DataFrame

from dotenv import load_dotenv
import logging

# %%
load_dotenv('../.env')
logger = logging.getLogger()
logger.setLevel(logging.INFO)

# %% [markdown]
# # API calls

# %%
# header: key generated by Sambanova Studio 

headers = {
    'content-type': 'application/json',
    'key': os.getenv('SAMBASTUDIO_KEY'),
}

# %%
# API endpoint urls

base_url = 'https://sjc1-demo1.sambanova.net'

# %%
# useful methods

def get_call(url, headers):
    response = requests.get(url, headers=headers)

    if response.status_code == 200:
        logging.info('GET request successful!')
        logging.debug(f'Response: {response.text}')
    else:
        logging.error(f'GET request failed with status code: {response.status_code}')
        logging.debug(f'Error message: {response.text}')
    return response

def post_call(url, params, headers):
    response = requests.post(url, json=params, headers=headers)

    if response.status_code == 200:
        logging.info('POST request successful!')
        logging.debug(f'Response: {response.text}')
    else:
        logging.error(f'POST request failed with status code: {response.status_code}')
        logging.debug(f'Error message: {response.text}')
    return response

def time_to_seconds(time_str):
    minutes, seconds = map(int, time_str.split(':'))
    return  minutes * 60 + seconds

def get_df_output(response_content: str) -> DataFrame:
    compressed_bytes = io.BytesIO(response_content)
    
    with tarfile.open(fileobj=compressed_bytes, mode="r:gz") as tar:
        output_tar_member = tar.getmember('results/output.csv')
        output_file = tar.extractfile(output_tar_member)
        output_df = pd.read_csv(io.BytesIO(output_file.read()), names = ['audio_path', 'results_path', 'speaker', 'start_time', 'end_time', 'unformatted_transcript', 'formatted_transcript'])
        output_df['start_time'] = output_df.apply(lambda x: time_to_seconds(x['start_time']), axis = 1)
        output_df['end_time'] = output_df.apply(lambda x: x['start_time'] + int(x['end_time'])/16000, axis = 1)
        output_df = output_df[['start_time', 'end_time', 'speaker', 'formatted_transcript']].rename(columns={'formatted_transcript': 'text'})
    
    return output_df

# %% [markdown]
# ## Datasets

# %%
# GET: status of requested dataset

datasets_url = '/api/datasets'
dataset_name = '/PCA_dataset'
url = base_url + datasets_url + dataset_name

get_call(url, headers)
# Out:
# ERROR:root:GET request failed with status code: 500
# <Response [500]>

# %%
# POST: creation of a new dataset

url = base_url + datasets_url

params = {
  'dataset_name': 'pca_test_v2',
  'application_field': 'speech',
  'job_type': ['batch_predict'],
  'language': 'english',
  'task': 'ASR With Diarization',
  'dataset_storage': 'LOCAL',
  'dataset_path': 'default/cap-engagements/datasets/local-dataset-42cf8587-6ce1-41bb-b7a4-2a069ae146bc', 
  'description': 'test',
  'file_type': 'test',
  'url': '',
}

post_call(url, params, headers)
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): sjc1-demo1.sambanova.net:443
# DEBUG:urllib3.connectionpool:https://sjc1-demo1.sambanova.net:443 "POST /api/datasets HTTP/1.1" 400 27
# ERROR:root:POST request failed with status code: 400
# DEBUG:root:Error message: {"detail":"field required"}
# <Response [400]>

# %% [markdown]
# After talking Varun Malyala, he says that "Uploading a Dataset is not supported via snsdk directly", so we'd need to add a new feature (Feb 26, 24). "Right now, Uploading a local Dataset is only possible via snapi or UI", so we're going to try with snapi later

# %% [markdown]
# ## Projects

# %%
# POST: creation of a new project

projects_url = '/api/projects'
url = base_url + projects_url

params = {
  'project_name': 'pca_project_test',
  'description': 'test project for pca'
}

post_call(url, params, headers)

# %%
# GET: status of requested project

project_name = '/pca_project_test'
url = base_url + projects_url + project_name

response = get_call(url, headers)
parsed_reponse = json.loads(response.text)
project_id = parsed_reponse['data']['project_id']
project_id
# Out:
# INFO:root:GET request successful!
# '5399bf56-201e-49d1-b663-dbf4678cebc4'

# %% [markdown]
# ## Batch inference

# %%
# POST: creation of a new batch inference

jobs_url = '/' + project_id + '/jobs'
url = base_url + projects_url + jobs_url

params = {
  'task': 'ASR With Diarization',
  'job_type': 'batch_predict',
  'job_name': 'pca_test_pipeline',
  'project': project_id,
  'model_checkpoint': 'Diarization_ASR_Pipeline_V2',
  'description': 'test diarization pipeline',
  'dataset': 'PCA_test',
}

response = post_call(url, params, headers)
parsed_reponse = json.loads(response.text)
job_id = parsed_reponse['data']['job_id']

# %%
# GET: status of batch inference

url = base_url + projects_url + jobs_url + '/' + job_id

response = get_call(url, headers)
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): sjc1-demo1.sambanova.net:443
# DEBUG:urllib3.connectionpool:https://sjc1-demo1.sambanova.net:443 "GET /api/projects/5399bf56-201e-49d1-b663-dbf4678cebc4/jobs/458c3b1b-7deb-4d9f-b0ad-12fd04b47f2a HTTP/1.1" 200 1251
# INFO:root:GET request successful!
# DEBUG:root:Response: {"data":{"job_name":"pca_test_pipeline","job_id":"458c3b1b-7deb-4d9f-b0ad-12fd04b47f2a","job_type":"batch_predict","project_id":"5399bf56-201e-49d1-b663-dbf4678cebc4","status":"EXIT_WITH_0","dataset_id":"42cf8587-6ce1-41bb-b7a4-2a069ae146bc","input_data_path":"default/cap-engagements/datasets/local-dataset-42cf8587-6ce1-41bb-b7a4-2a069ae146bc","model_checkpoint":"Diarization_ASR_Pipeline_V2","checkpoint_id":null,"hyperparams":[{"param_name":"sockets","value":3,"description":"Number of sockets each instance of the model uses"}],"user_id":"rodrigo.maldonado","time_created":"2024-02-23T20:45:37.866825+00:00","time_updated":"2024-02-23T20:47:44.084972+00:00","description":"test diarization pipeline","result_path":"default/cap-engagements/5399bf56-201e-49d1-b663-dbf4678cebc4/jobs/458c3b1b-7deb-4d9f-b0ad-12fd04b47f2a/results","parallel_instances":1,"load_state":false,"tenant_id":"a016b375-1e4a-46a5-8f66-03c3dbcb5f11","app_id":"b6aefdf7-02a4-4384-9c3c-8a81d735a54e","app_name":"ASR With Diarization","environment_variables":{},"rdu_arch":null,"dataset":"PCA_test","dataset_path":"default/cap-engagements/datasets/local-dataset-42cf8587-6ce1-41bb-b7a4-2a069ae146bc","model_id":"d7dffdd2-2d74-4ad6-9a03-3d3f5de94fa3","completion_percentage":100}}

# %% [markdown]
# ## Retrieve results

# %%
# GET: download results from pipeline

download_results_url = '/results/download'
url = base_url + projects_url + jobs_url + '/' + job_id + download_results_url

response = get_call(url, headers)
df = get_df_output(response.content)
df.head()
# Out:
# INFO:root:GET request successful!
#    start_time  end_time     speaker  \
# 0           0       2.5  SPEAKER_01
# 1           3      11.9  SPEAKER_00
# 2          11      12.3  SPEAKER_01
# 3          13      14.7  SPEAKER_00
# 4          14      14.6  SPEAKER_01
#
#                                                 text
# 0          Our Primeti 33. What is yet as emergency?
# 1  Yes, sir, I need to, uh, uh. I need an ambulan...
# 2                                             A car.
# 3                             Carol Wood Drive. Yes.
# 4                                                NaN

# %% [markdown]
# # Snapi

# %%
# !snapi app list
# Out:
# ASR With Diarization
# =====================================================
# Name                : ASR With Diarization
# ID                  : b6aefdf7-02a4-4384-9c3c-8a81d735a54e
# Playground          : False
# Prediction Input    : text
#
# ASR Without Diarization
# =====================================================
# Name                : ASR Without Diarization
# ID                  : a36cc322-dd36-40e3-9641-d87ac48fe2c4
# Playground          : False
# Prediction Input    : file
#
# CLIP
# =====================================================
# Name                : CLIP
# ID                  : 6c14325a-1be7-4e48-b38f-19b33745fc3b
# Playground          : False
# Prediction Input    : text
#
# Databox
# =====================================================
# Name                : Databox
# ID                  : 199e9684-785c-4df0-8dc3-49e808d8eba5
# Playground          : False
# Prediction Input    : text
#
# Deepseek 6.7B single socket
# =====================================================
# Name                : Deepseek 6.7B single socket
# ID                  : 2eeb4b7f-bc56-48c4-8814-ef9d1e8806b8
# Playground          : True
# Prediction Input    : text
#
# DePlot
# =====================================================
# Name                : DePlot
# ID                  : 40f16b58-72a9-404f-a7c3-afc0d27a2343
# Playground          : False
# Prediction Input    : file
#
# Dialog Act Classification
# =====================================================
# Name                : Dialog Act Classification
# ID                  : 0498c73a-5c03-456a-a645-3820728cfcae
# Playground          : False
# Prediction Input    : text
#
# Document Classification
# =====================================================
# Name                : Document Classification
# ID                  : a28085cc-da42-44f7-9d06-95f60d06e4cb
# Playground          : False
# Prediction Input    : text
#
# Fake Box for Testing
# =====================================================
# Name                : Fake Box for Testing
# ID                  : 3bcf5b6b-6d17-45ce-bb1e-543bed912f7b
# Playground          : False
# Prediction Input    : text
#
# FFN MNIST
# =====================================================
# Name                : FFN MNIST
# ID                  : baf32143-cfee-4911-a5dd-545453e85b36
# Playground          : False
# Prediction Input    : text
#
# Generative Tuning 1.5B
# =====================================================
# Name                : Generative Tuning 1.5B
# ID                  : e681c226-86be-40b2-9380-d2de11b19842
# Playground          : True
# Prediction Input    : text
#
# Generative Tuning 13B
# =====================================================
# Name                : Generative Tuning 13B
# ID                  : 57f6a3c8-1f04-488a-bb39-3cfc5b4a5d7a
# Playground          : True
# Prediction Input    : text
#
# Image Classification
# =====================================================
# Name                : Image Classification
# ID                  : 1c528476-f933-4168-b9fa-fb26a7180708
# Playground          : False
# Prediction Input    : text
#
# Llama 2 13B
# =====================================================
# Name                : Llama 2 13B
# ID                  : 1bf617cb-8afb-4bbd-b92f-c15ebfdca10b
# Playground          : True
# Prediction Input    : text
#
# Llama 2 70B
# =====================================================
# Name                : Llama 2 70B
# ID                  : 82254d3b-7239-458b-9da8-da1aca9b7fba
# Playground          : True
# Prediction Input    : text
#
# Llama 2 7B
# =====================================================
# Name                : Llama 2 7B
# ID                  : ec012370-6ffa-4a3a-b230-2c62613f1d89
# Playground          : True
# Prediction Input    : text
#
# Llama 2 7B 8-socket
# =====================================================
# Name                : Llama 2 7B 8-socket
# ID                  : 21d706a3-d9fb-4998-aa9b-ad9ff2c3a920
# Playground          : True
# Prediction Input    : text
#
# Low Data Resource Text Classification
# =====================================================
# Name                : Low Data Resource Text Classification
# ID                  : 35f812a5-bb33-44e0-9e63-10191e44bb0c
# Playground          : False
# Prediction Input    : text
#
# Named Entity Recognition
# =====================================================
# Name                : Named Entity Recognition
# ID                  : c27a105f-d0be-4bef-b2a4-4d6bf747ebdc
# Playground          : False
# Prediction Input    : text
#
# Reranking
# =====================================================
# Name                : Reranking
# ID                  : f25c8247-f73a-4dd9-9871-d5c10675239c
# Playground          : False
# Prediction Input    : text
#
# Sentence Detection
# =====================================================
# Name                : Sentence Detection
# ID                  : f67c5390-da52-4105-ae17-12434fa7d03b
# Playground          : False
# Prediction Input    : text
#
# Sentiment Analysis
# =====================================================
# Name                : Sentiment Analysis
# ID                  : 6db6d59f-ae40-4513-b218-4218fc97e40f
# Playground          : False
# Prediction Input    : text
#
# Simple Text Classifier
# =====================================================
# Name                : Simple Text Classifier
# ID                  : 3aaf5b6b-6d17-45ce-bb1e-543bed912f7b
# Playground          : False
# Prediction Input    : text
#
# Simple Text Classifier Pipeline
# =====================================================
# Name                : Simple Text Classifier Pipeline
# ID                  : cbc92c2f-2a01-4ef5-b85a-78ee7f392005
# Playground          : False
# Prediction Input    : text
#
# Speaker Diarization
# =====================================================
# Name                : Speaker Diarization
# ID                  : cbba6d31-104a-4295-ac21-7e91da09ab9b
# Playground          : False
# Prediction Input    : file
#
# Speech Recognition
# =====================================================
# Name                : Speech Recognition
# ID                  : ecf84906-0924-4ce1-a1a2-c008f5334820
# Playground          : False
# Prediction Input    : file
#
# Text Embedding
# =====================================================
# Name                : Text Embedding
# ID                  : 89fbfbe6-ee77-4f5c-9ff6-56e2ab69f6ee
# Playground          : False
# Prediction Input    : text

# %%
# app id for ASR With Diarization

app_id = 'b6aefdf7-02a4-4384-9c3c-8a81d735a54e'

# %%
# we have to reference a json file that has the path of the data set that we'll upload

# !snapi dataset add --help
# Out:
#
#  Usage: snapi dataset add [OPTIONS]
#
#  Add a new dataset
#
# ╭─ Options ────────────────────────────────────────────────────────────────────╮
# │    --file                          TEXT                                      │
# │ *  --dataset-name       -n         TEXT  Dataset name [default: None]        │
# │                                          [required]                          │
# │ *  --apps               -apps      TEXT  App IDs or names to which this      │
# │                                          Dataset will be associated          │
# │                                          [default: None]                     │
# │                                          [required]                          │
# │    --metadata-file      -mf        TEXT  Metadata File containing dataset    │
# │                                          metadata file paths. Only           │
# │                                          .yaml/.json files are supported.    │
# │                                          Example -                           │
# │                                          Dataset Metadata file schema        │
# │                                          {                                   │
# │                                          "labels_file":                      │
# │                                          "path/to/labels_file",              │
# │                                          "train_filepath":                   │
# │                                          "path/to/train_filepath",           │
# │                                          "validation_filepath":              │
# │                                          "path/to/validation_filepath",      │
# │                                          "test_filepath":                    │
# │                                          "path/to/test_filepath",            │
# │                                          }                                   │
# │    --description        -d         TEXT  Free-form text description of       │
# │                                          dataset                             │
# │    --file_type          -ft        TEXT  Free-form text file types in        │
# │                                          dataset                             │
# │    --url                -u         TEXT  Free-form text url source of        │
# │                                          dataset                             │
# │    --application_field  -af        TEXT  Field of application of dataset     │
# │    --language           -l         TEXT  Language of NLP dataset             │
# │ *  --job_type           -j         TEXT  Job types for dataset (either       │
# │                                          'train' & 'evaluation' or           │
# │                                          'batch_predict')                    │
# │                                          [default: None]                     │
# │                                          [required]                          │
# │ *  --source_type        -st        TEXT  Dataset Source type (either 'local' │
# │                                          & 'aws' or 'localMachine')          │
# │                                          [default: None]                     │
# │                                          [required]                          │
# │ *  --source_file        -sf        TEXT  Source File. Only .yaml/.json files │
# │                                          are supported. source file should   │
# │                                          contain one of source configs for   │
# │                                          local, aws or localMachine          │
# │                                          1. Local Config                     │
# │                                          {"source_path": "string"  // The    │
# │                                          local source path on NFS.},         │
# │                                          2. AWS Config                       │
# │                                          {                                   │
# │                                          "bucket": "string",            //   │
# │                                          The AWS S3 bucket name.             │
# │                                          "folder": "string",            //   │
# │                                          The folder or prefix within the     │
# │                                          bucket.                             │
# │                                          "accessKeyId": "string",       //   │
# │                                          AWS Access Key ID for               │
# │                                          authentication.                     │
# │                                          "secretAccessKey": "string",   //   │
# │                                          AWS Secret Access Key for           │
# │                                          authentication.                     │
# │                                          "region": "string"             //   │
# │                                          AWS region where the S3 bucket is   │
# │                                          located.                            │
# │                                          },                                  │
# │                                          3. Local Machine Config             │
# │                                          {"source_path": "string"  // The    │
# │                                          source path on the local machine.}  │
# │                                          [default: None]                     │
# │                                          [required]                          │
# │    --test               -t               Flag for test                       │
# │    --help                                Show this message and exit.         │
# ╰──────────────────────────────────────────────────────────────────────────────╯

# %%
command = f'echo yes | snapi dataset add \
    --dataset-name local_file_test_3 \
    --job_type batch_predict \
    --apps b6aefdf7-02a4-4384-9c3c-8a81d735a54e \
    --source_type localMachine \
    --source_file ../data/datasets/source.json \
    --application_field language \
    --language english \
    --description test_description_3'
os.system(command)
# Out:
# Folder Information:
#   - Number of Files: 1
#   - Total Size: 19.62 MB
#
# Are you sure you want to proceed? (yes/no)
# : Uploading files
# Dataset folder upload complete: ../test_data/
# Dataset added successfully.
# Time taken to upload the dataset: 5.327938079833984 seconds
# 0

# %% [markdown]
# # ASR Pipeline

# %% [markdown]
# Progress so far about the ASR pipeline. Next, a list with the tasks that still need to be done:
# - There's an error with dataset API search or GET (more details [here](https://sjc1-demo1.sambanova.net/api/docs#/)), which are returning 500 everytime they're getting info from a previously deleted dataset. I was checking this issue with Sharad Venkateswaran on a help-sambastudio channel
# - Integration tests with all methods. So far, every method has been tested, but we need to do integration tests as next step. Process will be: dataset creation, project creation, job creation, job monitoring, and retrieve results. Also, this pipeline contemplates as input a path with the audio file, and outputs a csv, so take that in mind. Contact Jorge Piedrahita or Rodrigo Maldonado for more details
# - Documentation on class and methods

# %%
def load_config(file_path):
    with open(file_path, 'r') as file:
        config = yaml.safe_load(file)
    return config

config = load_config('../config.yaml')

PENDING_RDU_JOB_STATUS = 'PENDING_RDU'
SUCCESS_JOB_STATUS = 'EXIT_WITH_0'

# %%
class BatchASRProcessor():
    
    def __init__(self, config) -> None:
        self.headers = {
            'content-type': 'application/json',
            'key': os.getenv('SAMBASTUDIO_KEY'),
        }
        self.datasets_path = config['asr']['datasets']['datasets_path']
        self.dataset_id = None
        self.dataset_name = config['asr']['datasets']['dataset_name']
        self.dataset_description = config['asr']['datasets']['dataset_description']
        self.dataset_source_type = config['asr']['datasets']['dataset_source_type']
        self.dataset_source_file = config['asr']['datasets']['dataset_source_file']
        self.dataset_language = config['asr']['datasets']['dataset_language']
        
        self.asr_with_diarization_app_id = config['asr']['apps']['asr_with_diarization_app_id']
        self.application_field = config['asr']['apps']['application_field']
        
        self.base_url = config['asr']['urls']['base_url']
        self.datasets_url = config['asr']['urls']['datasets_url'] 
        self.projects_url = config['asr']['urls']['projects_url'] 
        self.jobs_url = config['asr']['urls']['jobs_url'] 
        self.download_results_url = config['asr']['urls']['download_results_url'] 
    
        self.project_name = config['asr']['projects']['project_name']
        self.project_description = config['asr']['projects']['project_description']
        
        self.job_name = config['asr']['jobs']['job_name']
        self.job_task = config['asr']['jobs']['job_task']
        self.job_type = config['asr']['jobs']['job_type']
        self.job_description = config['asr']['jobs']['job_description']
        self.model_checkpoint = config['asr']['jobs']['model_checkpoint']
        
        self.output_path = config['asr']['output']['output_path']
        
        
    def _get_call(self, url, params = None, success_message = None):
        response = requests.get(url, params=params, headers=self.headers)

        if response.status_code == 200:
            logging.info('GET request successful!')
            logging.info(success_message)
            logging.debug(f'Response: {response.text}')
        else:
            logging.error(f'GET request failed with status code: {response.status_code}')
            raise Exception(f'Error message: {response.text}')
        return response

    def _post_call(self, url, params, success_message = None):
        response = requests.post(url, json=params, headers=self.headers)

        if response.status_code == 200:
            logging.info('POST request successful!')
            logging.info(success_message)
            logging.debug(f'Response: {response.text}')
        else:
            logging.error(f'POST request failed with status code: {response.status_code}')
            raise Exception(f'Error message: {response.text}')
        return response
    
    def _delete_call(self, url):
        response = requests.delete(url, headers=self.headers)    
        if response.status_code == 200:
            logging.info(f'Dataset {self.dataset_name} deleted successfully.')
            logging.debug(f'Response: {response.text}')
        else:
            logging.error(f'Failed to delete the resource. Status code: {response.status_code}')
            raise Exception(f'Error message: {response.text}')    
        return response

    def _time_to_seconds(self, time_str):
        minutes, seconds = map(int, time_str.split(':'))
        return  minutes * 60 + seconds

    def _get_df_output(self, response_content: str) -> DataFrame:
        compressed_bytes = io.BytesIO(response_content)
        
        with tarfile.open(fileobj=compressed_bytes, mode="r:gz") as tar:
            output_tar_member = tar.getmember(self.output_path)
            output_file = tar.extractfile(output_tar_member)
            output_df = pd.read_csv(io.BytesIO(output_file.read()), names = ['audio_path', 'results_path', 'speaker', 'start_time', 'sample_duration', 'unformatted_transcript', 'formatted_transcript'])
            output_df['start_time'] = output_df.apply(lambda x: self._time_to_seconds(x['start_time']), axis = 1)
            output_df['end_time'] = output_df.apply(lambda x: x['start_time'] + int(x['sample_duration'])/16000, axis = 1)
            output_df = output_df[['start_time', 'end_time', 'speaker', 'formatted_transcript']].rename(columns={'formatted_transcript': 'text'})
        
        return output_df

    def search_dataset(self):
        url = self.base_url + self.datasets_url + '/search'
        params = {
            'dataset_name': self.dataset_name
        }
        response = self._get_call(url, params, f'Dataset {self.dataset_name} found in SambaStudio')
        parsed_reponse = json.loads(response.text)
        return parsed_reponse['data']['dataset_id']

    def delete_dataset(self):
        dataset_id = self.search_dataset()
        url = self.base_url + self.datasets_url + '/' + dataset_id
        response = self._delete_call(url)
        logging.info(response.text)
        
    def create_dataset(self, path):
                
        # create pca directory and source.json file
        pca_directory = self.datasets_path + '/' + self.dataset_name
        
        if not os.path.isdir(self.datasets_path):
            os.mkdir(self.datasets_path) 
            
        if not os.path.isdir(pca_directory):
            logging.info(f'Datasets path: {pca_directory} wan\'t found')
            
            source_file_data = {
                "source_path": pca_directory
            }
            with open(self.dataset_source_file, 'w') as json_file:
                json.dump(source_file_data, json_file)
            os.mkdir(pca_directory)
            
            logging.info(f'PCA Directory: {pca_directory} created')
    
        # validate audio file
        audio_format = path.split('.')[-1]
        
        if audio_format == 'mp3':
            shutil.copyfile(path, pca_directory + '/pca_file.mp3')
        elif audio_format == 'wav':
            shutil.copyfile(path, pca_directory + '/pca_file.wav')
        else:
            raise Exception('Only mp3 and wav audio files supported')
        
        # create dataset
        command = f'echo yes | snapi dataset add \
            --dataset-name {self.dataset_name} \
            --job_type {self.job_type} \
            --apps {self.asr_with_diarization_app_id} \
            --source_type {self.dataset_source_type} \
            --source_file {self.dataset_source_file} \
            --application_field {self.application_field} \
            --language {self.dataset_language} \
            --description "{self.dataset_description}"'
        
        os.system(command)
        logging.info(f'Creating dataset: {self.dataset_name}')
        
        self.dataset_id
        
        # self.delete_dataset()
    
    def create_load_project(self):

        url = self.base_url + self.projects_url + '/' + self.project_name

        response = self._get_call(url, success_message=f'Project {self.project_name} found in SambaStudio')
        not_found_error_message = f"{self.project_name} not found"

        if not_found_error_message in response.text:
            
            logging.info(f'Project {self.project_name} wasn\'t found in SambaStudio')
            
            url = base_url + projects_url

            params = {
                'project_name': self.project_name,
                'description': self.project_description
            }

            response = self._post_call(url, params, success_message=f'Project {self.project_name} created!')

        parsed_reponse = json.loads(response.text)
        project_id = parsed_reponse['data']['project_id']
        return project_id
    
    def run_job(self, project_id):
        
        url = self.base_url + self.projects_url + self.jobs_url.format(project_id=project_id)
        
        params = {
            'task': self.job_task,
            'job_type': self.job_type,
            'job_name': self.job_name,
            'project': project_id,
            'model_checkpoint': self.model_checkpoint,
            'description': self.job_description,
            'dataset': self.dataset_name,
        }

        response = self._post_call(url, params, success_message='Job running')
        parsed_reponse = json.loads(response.text)
        job_id = parsed_reponse['data']['job_id']
        
        return job_id
    
    def check_job_progress(self, project_id, job_id):

        url = self.base_url + self.projects_url + self.jobs_url.format(project_id=project_id) + '/' + job_id

        status = PENDING_RDU_JOB_STATUS
        while status != SUCCESS_JOB_STATUS:
            response = self._get_call(url, success_message='Still waiting for job to finish')
            parsed_reponse = json.loads(response.text)   
            status = parsed_reponse['data']['status']
            logging.info(f'Job status: {status}')
            if status == SUCCESS_JOB_STATUS:
                logging.info(f'Job finished!')
                break
            time.sleep(10)
        
        return True
    
    def check_dataset_creation_progress(self):
        # TO-DO: check if dataset creation is async. Then, this method will be necessary to know when it finishes and continue with the pipeline.
        # Take 'check_job_progress' as reference
        url = self.base_url + self.datasets_url + '/' + self.dataset_name
        print(url)
        response = self._get_call(url)
        print(response.text)
        
        return True
    
    def retrieve_results(self, project_id, job_id):
        url = self.base_url + self.projects_url + self.jobs_url.format(project_id=project_id) + '/' + job_id + self.download_results_url

        response = self._get_call(url, success_message='Results downloaded!')
        df = self._get_df_output(response.content)
        return df

# %%
asr = BatchASRProcessor(config)

# %%
# !snapi dataset list
# Out:
# Caltech_256_Clip
# ================
#
# PATH              : common/datasets/1ea54b9c-f1f6-49d4-91f6-e230eec7c259/dataset
# APPS              : ['6c14325a-1be7-4e48-b38f-19b33745fc3b']
# USER              : None
# STATUS            : Available
# TIME CREATED      : 0001-01-01T00:00:00+00:00
#
#
# Caltech_256_Clip_V2
# ===================
#
# PATH              : common/datasets/63277371-e8c1-4c2c-80be-f5d25ab3c3e4/dataset
# APPS              : ['6c14325a-1be7-4e48-b38f-19b33745fc3b']
# USER              : None
# STATUS            : Available
# TIME CREATED      : 0001-01-01T00:00:00+00:00
#
#
# Generative_Inference_Dataset
# ============================
#
# PATH              : common/datasets/17be1fa1-2ed2-4503-9ccc-99be2c905010/dataset
# APPS              : ['e681c226-86be-40b2-9380-d2de11b19842', 'ec012370-6ffa-4a3a-b230-2c62613f1d89', '1bf617cb-8afb-4bbd-b92f-c15ebfdca10b', '57f6a3c8-1f04-488a-bb39-3cfc5b4a5d7a']
# USER              : None
# STATUS            : AvailableToDownload
# TIME CREATED      : 0001-01-01T00:00:00+00:00
#
#
# Super_Glue_4k_SS
# ================
#
# PATH              : common/datasets/b53ff7b7-bf63-4dbd-919e-33b36b2ba11f/dataset
# APPS              : ['21d706a3-d9fb-4998-aa9b-ad9ff2c3a920', 'ec012370-6ffa-4a3a-b230-2c62613f1d89', '1bf617cb-8afb-4bbd-b92f-c15ebfdca10b']
# USER              : None
# STATUS            : AvailableToDownload
# TIME CREATED      : 0001-01-01T00:00:00+00:00
#
#
# GPT_13B_8k_SS_Toy_Training_Dataset
# ==================================
#
# PATH              : common/datasets/9bac6a44-92b2-40ac-9a4d-ba72038ac27b/dataset
# APPS              : ['57f6a3c8-1f04-488a-bb39-3cfc5b4a5d7a']
# USER              : None
# STATUS            : AvailableToDownload
# TIME CREATED      : 0001-01-01T00:00:00+00:00
#
#
# openthaigpt_50k_IT0913
# ======================
#
# PATH              : common/datasets/8f30e146-5871-4cf4-85cf-7d96bf5255ac/dataset
# APPS              : ['21d706a3-d9fb-4998-aa9b-ad9ff2c3a920', 'ec012370-6ffa-4a3a-b230-2c62613f1d89', '1bf617cb-8afb-4bbd-b92f-c15ebfdca10b']
# USER              : None
# STATUS            : AvailableToDownload
# TIME CREATED      : 0001-01-01T00:00:00+00:00
#
#
# ASR_Without_Diarization_Dataset
# ===============================
#
# PATH              : common/datasets/librispeech_modelbox/
# APPS              : ['a36cc322-dd36-40e3-9641-d87ac48fe2c4']
# USER              : None
# STATUS            : Available
# TIME CREATED      : 2021-08-26T00:00:00+00:00
#
#
# GPT_1.5B_Training_Dataset
# =========================
#
# PATH              : common/datasets/ggt_sentiment_analysis/hdf5_single_avoid_overflow/hdf5
# APPS              : ['e681c226-86be-40b2-9380-d2de11b19842']
# USER              : None
# STATUS            : Available
# TIME CREATED      : 2021-08-26T00:00:00+00:00
#
#
# Disaster_Train_Dataset
# ======================
#
# PATH              : common/datasets/textclass_train/
# APPS              : ['3aaf5b6b-6d17-45ce-bb1e-543bed912f7b']
# USER              : None
# STATUS            : Available
# TIME CREATED      : 2021-08-26T00:00:00+00:00
#
#
# Disaster_Test_Dataset
# =====================
#
# PATH              : common/datasets/textclass_test/
# APPS              : ['3aaf5b6b-6d17-45ce-bb1e-543bed912f7b']
# USER              : None
# STATUS            : Available
# TIME CREATED      : 2021-08-26T00:00:00+00:00
#
#
# Dialog_Act_Classification_Data
# ==============================
#
# PATH              : common/datasets/dialogue_act_classification_jsonl_data/
# APPS              : ['0498c73a-5c03-456a-a645-3820728cfcae']
# USER              : None
# STATUS            : Available
# TIME CREATED      : 2021-08-26T00:00:00+00:00
#
#
# Sentiment_Analysis
# ==================
#
# PATH              : common/datasets/sentiment_analysis/
# APPS              : ['6db6d59f-ae40-4513-b218-4218fc97e40f']
# USER              : None
# STATUS            : Available
# TIME CREATED      : 2021-08-26T00:00:00+00:00
#
#
# Pipeline_Test_Dataset
# =====================
#
# PATH              : common/datasets/textclass_test/
# APPS              : ['cbc92c2f-2a01-4ef5-b85a-78ee7f392005']
# USER              : None
# STATUS            : Available
# TIME CREATED      : 2021-08-26T00:00:00+00:00
#
#
# Arxiv
# =====
#
# PATH              : common/datasets/gpt_small_doc_classification/arxiv_dataset/
# APPS              : ['a28085cc-da42-44f7-9d06-95f60d06e4cb']
# USER              : None
# STATUS            : Available
# TIME CREATED      : 2021-08-26T00:00:00+00:00
#
#
# CONLL_2003
# ==========
#
# PATH              : common/datasets/CONLL2003/
# APPS              : ['c27a105f-d0be-4bef-b2a4-4d6bf747ebdc']
# USER              : None
# STATUS            : Available
# TIME CREATED      : 2021-08-26T00:00:00+00:00
#
#
# GPT_1.5B_Inference_Dataset
# ==========================
#
# PATH              : common/datasets/toy_generative
# APPS              : ['e681c226-86be-40b2-9380-d2de11b19842']
# USER              : None
# STATUS            : Available
# TIME CREATED      : 2021-08-26T00:00:00+00:00
#
#
# GPT_13B_Inference_Dataset
# =========================
#
# PATH              : common/datasets/toy_generative
# APPS              : ['57f6a3c8-1f04-488a-bb39-3cfc5b4a5d7a']
# USER              : None
# STATUS            : Available
# TIME CREATED      : 2021-08-26T00:00:00+00:00
#
#
# Call_Center_Dataset
# ===================
#
# PATH              : common/datasets/call_center/low_data_resource/callcenter_ts_dataset/
# APPS              : ['35f812a5-bb33-44e0-9e63-10191e44bb0c']
# USER              : None
# STATUS            : Available
# TIME CREATED      : 2021-08-26T00:00:00+00:00
#
#
# ASR_With_Diarization_Dataset
# ============================
#
# PATH              : common/datasets/speaker_diarization/
# APPS              : ['b6aefdf7-02a4-4384-9c3c-8a81d735a54e']
# USER              : None
# STATUS            : Available
# TIME CREATED      : 2021-08-26T00:00:00+00:00
#
#
# Speaker_Diarization
# ===================
#
# PATH              : common/datasets/speaker_diarization/
# APPS              : ['cbba6d31-104a-4295-ac21-7e91da09ab9b']
# USER              : None
# STATUS            : Available
# TIME CREATED      : 2021-08-26T00:00:00+00:00
#
#
# Restore_Punctuation_Data
# ========================
#
# PATH              : common/datasets/restore_punctuation_data/
# APPS              : ['f67c5390-da52-4105-ae17-12434fa7d03b']
# USER              : None
# STATUS            : Available
# TIME CREATED      : 2021-11-22T00:00:00+00:00
#
#
# Librispeech
# ===========
#
# PATH              : common/datasets/librispeech_modelbox/
# APPS              : ['ecf84906-0924-4ce1-a1a2-c008f5334820']
# USER              : None
# STATUS            : Available
# TIME CREATED      : 2022-11-08T00:00:00+00:00
#
#
# GPT_13B_Training_Dataset
# ========================
#
# PATH              : common/datasets/squad_clm/ggt_2048/hdf5
# APPS              : ['57f6a3c8-1f04-488a-bb39-3cfc5b4a5d7a']
# USER              : None
# STATUS            : Available
# TIME CREATED      : 2023-01-16T00:00:00+00:00
#
#
# FiQA
# ====
#
# PATH              : common/datasets/semantic_search/fiqa_document_reranker_data_dir
# APPS              : ['f25c8247-f73a-4dd9-9871-d5c10675239c']
# USER              : None
# STATUS            : Available
# TIME CREATED      : 2023-02-28T00:00:00+00:00
#
#
# Caltech_256
# ===========
#
# PATH              : common/datasets/vit_b_classification/1.1.0/Caltech_256
# APPS              : ['1c528476-f933-4168-b9fa-fb26a7180708']
# USER              : None
# STATUS            : Available
# TIME CREATED      : 2023-03-22T00:00:00+00:00
#
#
# openwebtext_ss4096_32k_vocab
# ============================
#
# PATH              : common/datasets/b9dda5a7-c0d3-4d34-aa84-6b893c0abf5c/dataset
# APPS              : ['21d706a3-d9fb-4998-aa9b-ad9ff2c3a920', 'ec012370-6ffa-4a3a-b230-2c62613f1d89', '1bf617cb-8afb-4bbd-b92f-c15ebfdca10b']
# USER              : None
# STATUS            : AvailableToDownload
# TIME CREATED      : 2023-12-12T16:06:47.621615+00:00
#
#
# adi_query_decomp_v1
# ===================
#
# PATH              : default/cap-engagements/datasets/local-dataset-e29da3f2-abcf-11ee-894c-a6da4d8c1955
# APPS              : ['21d706a3-d9fb-4998-aa9b-ad9ff2c3a920', 'ec012370-6ffa-4a3a-b230-2c62613f1d89']
# USER              : cody.macdonald
# STATUS            : Available
# TIME CREATED      : 2024-01-05T13:40:22.293811+00:00
#
#
# adi-query-decomp-v2
# ===================
#
# PATH              : default/cap-engagements/datasets/local-dataset-f4f61c54-ad79-11ee-9d28-a6da4d8c1955
# APPS              : ['ec012370-6ffa-4a3a-b230-2c62613f1d89']
# USER              : cody.macdonald
# STATUS            : Available
# TIME CREATED      : 2024-01-07T16:30:00.410133+00:00
#
#
# adi_switchgear_llama2_7b_v1
# ===========================
#
# PATH              : default/cap-engagements/datasets/local-dataset-307823dc-af49-11ee-b8d3-a6da4d8c1955
# APPS              : ['ec012370-6ffa-4a3a-b230-2c62613f1d89']
# USER              : cody.macdonald
# STATUS            : Available
# TIME CREATED      : 2024-01-09T23:45:59.098759+00:00
#
#
# adi_switchgear_llama2_v2
# ========================
#
# PATH              : default/cap-engagements/datasets/local-dataset-0fbae646-afe1-11ee-bf32-a6da4d8c1955
# APPS              : ['ec012370-6ffa-4a3a-b230-2c62613f1d89']
# USER              : cody.macdonald
# STATUS            : Available
# TIME CREATED      : 2024-01-10T17:53:30.278638+00:00
#
#
# Pretraining-squad-sql-dataset
# =============================
#
# PATH              : default/cap-engagements/datasets/local-dataset-e952483e-b06f-11ee-a3fd-a6da4d8c1955
# APPS              : ['21d706a3-d9fb-4998-aa9b-ad9ff2c3a920']
# USER              : amit.kushwaha
# STATUS            : Available
# TIME CREATED      : 2024-01-11T12:58:16.269633+00:00
#
#
# fine-tune-nstext2sql
# ====================
#
# PATH              : default/cap-engagements/datasets/local-dataset-d4ca3d6a-b086-11ee-b409-a6da4d8c1955
# APPS              : ['21d706a3-d9fb-4998-aa9b-ad9ff2c3a920', 'ec012370-6ffa-4a3a-b230-2c62613f1d89']
# USER              : amit.kushwaha
# STATUS            : Available
# TIME CREATED      : 2024-01-11T13:46:48.696094+00:00
#
#
# adi_pretaining_chunks_md
# ========================
#
# PATH              : default/cap-engagements/datasets/local-dataset-cfc0ec26-b098-11ee-928f-a6da4d8c1955
# APPS              : ['ec012370-6ffa-4a3a-b230-2c62613f1d89']
# USER              : cody.macdonald
# STATUS            : Available
# TIME CREATED      : 2024-01-11T15:48:33.156200+00:00
#
#
# adi_switchgear_llama2_7b_v4
# ===========================
#
# PATH              : default/cap-engagements/datasets/local-dataset-d67969ca-b16b-11ee-822f-a6da4d8c1955
# APPS              : ['ec012370-6ffa-4a3a-b230-2c62613f1d89']
# USER              : cody.macdonald
# STATUS            : Available
# TIME CREATED      : 2024-01-12T16:59:07.933529+00:00
#
#
# adi_switchgear_llama2_7b_v4_2
# =============================
#
# PATH              : default/cap-engagements/datasets/local-dataset-33d82a6a-b195-11ee-8352-a6da4d8c1955
# APPS              : ['ec012370-6ffa-4a3a-b230-2c62613f1d89']
# USER              : cody.macdonald
# STATUS            : Available
# TIME CREATED      : 2024-01-12T21:58:39.420950+00:00
#
#
# adi-stepdown-question-expert-data-v4
# ====================================
#
# PATH              : default/cap-engagements/datasets/local-dataset-5aa00aee-b219-11ee-8400-a6da4d8c1955
# APPS              : ['ec012370-6ffa-4a3a-b230-2c62613f1d89']
# USER              : cody.macdonald
# STATUS            : Available
# TIME CREATED      : 2024-01-13T13:42:29.683374+00:00
#
#
# adi-stepdown-answer-expert-data-v4
# ==================================
#
# PATH              : default/cap-engagements/datasets/local-dataset-ab458942-b219-11ee-8b3f-a6da4d8c1955
# APPS              : ['ec012370-6ffa-4a3a-b230-2c62613f1d89']
# USER              : cody.macdonald
# STATUS            : Available
# TIME CREATED      : 2024-01-13T13:43:23.279493+00:00
#
#
# adi_question_expert_v5
# ======================
#
# PATH              : default/cap-engagements/datasets/local-dataset-9a13dac2-b4b5-11ee-837d-a6da4d8c1955
# APPS              : ['ec012370-6ffa-4a3a-b230-2c62613f1d89']
# USER              : cody.macdonald
# STATUS            : Available
# TIME CREATED      : 2024-01-16T21:25:28.960081+00:00
#
#
# adi_llama_v5_answer_expert
# ==========================
#
# PATH              : default/cap-engagements/datasets/local-dataset-719a3fa2-b4b8-11ee-a44c-a6da4d8c1955
# APPS              : ['ec012370-6ffa-4a3a-b230-2c62613f1d89']
# USER              : cody.macdonald
# STATUS            : Available
# TIME CREATED      : 2024-01-16T21:45:28.118063+00:00
#
#
# adi-stepdown-question-expert-expanded-v1
# ========================================
#
# PATH              : default/cap-engagements/datasets/local-dataset-09793e60-b9f8-11ee-993e-a6da4d8c1955
# APPS              : ['ec012370-6ffa-4a3a-b230-2c62613f1d89']
# USER              : cody.macdonald
# STATUS            : Available
# TIME CREATED      : 2024-01-23T14:02:53.506539+00:00
#
#
# Pretraining-squad-sql-smol-dataset
# ==================================
#
# PATH              : default/cap-engagements/datasets/local-dataset-f94d2dce-ba17-11ee-94b1-a6da4d8c1955
# APPS              : ['21d706a3-d9fb-4998-aa9b-ad9ff2c3a920', 'ec012370-6ffa-4a3a-b230-2c62613f1d89']
# USER              : amit.kushwaha
# STATUS            : Available
# TIME CREATED      : 2024-01-23T17:54:05.654514+00:00
#
#
# adi_switchgear_llama_question_expert_expanded_v2
# ================================================
#
# PATH              : default/cap-engagements/datasets/local-dataset-f502c35c-babf-11ee-a42f-a6da4d8c1955
# APPS              : ['ec012370-6ffa-4a3a-b230-2c62613f1d89']
# USER              : cody.macdonald
# STATUS            : Available
# TIME CREATED      : 2024-01-24T13:54:09.437851+00:00
#
#
# adi_switchgear_llama_question_expert_expanded_v2_2
# ==================================================
#
# PATH              : default/cap-engagements/datasets/local-dataset-a7f14e1c-bd21-11ee-84f8-a6da4d8c1955
# APPS              : ['ec012370-6ffa-4a3a-b230-2c62613f1d89']
# USER              : cody.macdonald
# STATUS            : Available
# TIME CREATED      : 2024-01-27T14:38:43.777666+00:00
#
#
# adi_switchgear_llama_question_expert_expanded_v3
# ================================================
#
# PATH              : default/cap-engagements/datasets/local-dataset-0a565e5e-c046-11ee-99d7-a6da4d8c1955
# APPS              : ['ec012370-6ffa-4a3a-b230-2c62613f1d89']
# USER              : cody.macdonald
# STATUS            : Available
# TIME CREATED      : 2024-01-31T14:39:07.425705+00:00
#
#
# adi_stepdown-q_llama_v4
# =======================
#
# PATH              : default/cap-engagements/datasets/local-dataset-d98aa9f4-c2bd-11ee-a67c-a6da4d8c1955
# APPS              : ['ec012370-6ffa-4a3a-b230-2c62613f1d89']
# USER              : cody.macdonald
# STATUS            : Available
# TIME CREATED      : 2024-02-03T17:59:16.232056+00:00
#
#
# adi_q_expert_e2e_1
# ==================
#
# PATH              : default/cap-engagements/datasets/local-dataset-0c5b8194-c527-11ee-8386-a6da4d8c1955
# APPS              : ['ec012370-6ffa-4a3a-b230-2c62613f1d89']
# USER              : cody.macdonald
# STATUS            : Available
# TIME CREATED      : 2024-02-06T19:37:16.720648+00:00
#
#
# adi_q_expert_e2e_2
# ==================
#
# PATH              : default/cap-engagements/datasets/local-dataset-2e899404-c6df-11ee-8c4a-56de290e63a0
# APPS              : ['ec012370-6ffa-4a3a-b230-2c62613f1d89']
# USER              : cody.macdonald
# STATUS            : Available
# TIME CREATED      : 2024-02-09T00:07:40.592283+00:00
#
#
# e2e_2_full
# ==========
#
# PATH              : default/cap-engagements/datasets/local-dataset-6c410efe-c783-11ee-b7a9-56de290e63a0
# APPS              : ['ec012370-6ffa-4a3a-b230-2c62613f1d89']
# USER              : cody.macdonald
# STATUS            : Available
# TIME CREATED      : 2024-02-09T19:44:18.019234+00:00
#
#
# e2e_2_full_modified
# ===================
#
# PATH              : default/cap-engagements/datasets/local-dataset-6c734fd4-c843-11ee-bc5b-56de290e63a0
# APPS              : ['ec012370-6ffa-4a3a-b230-2c62613f1d89']
# USER              : cody.macdonald
# STATUS            : Available
# TIME CREATED      : 2024-02-10T18:38:01.166714+00:00
#
#
# e2e_3_full_modified
# ===================
#
# PATH              : default/cap-engagements/datasets/local-dataset-d3916808-c8e9-11ee-b7bb-56de290e63a0
# APPS              : ['ec012370-6ffa-4a3a-b230-2c62613f1d89']
# USER              : cody.macdonald
# STATUS            : Available
# TIME CREATED      : 2024-02-11T14:30:12.893064+00:00
#
#
# e2e_qa3_w_unknown_full2
# =======================
#
# PATH              : default/cap-engagements/datasets/local-dataset-dfb225a6-c9f1-11ee-a35b-56de290e63a0
# APPS              : ['ec012370-6ffa-4a3a-b230-2c62613f1d89']
# USER              : cody.macdonald
# STATUS            : Available
# TIME CREATED      : 2024-02-12T21:59:40.663517+00:00
#
#
# Coding_Generative_Inference_Dataset
# ===================================
#
# PATH              : common/datasets/7198371d-0f70-4287-8645-8e3807782d30/dataset
# APPS              : ['2eeb4b7f-bc56-48c4-8814-ef9d1e8806b8']
# USER              : None
# STATUS            : AvailableToDownload
# TIME CREATED      : 2024-02-15T16:12:13.601722+00:00
#
#
# imran_scrap_datasets
# ====================
#
# PATH              : default/cap-engagements/datasets/local-dataset-b8b3b1d4-06e9-468c-8d55-1583936b0feb
# APPS              : ['82254d3b-7239-458b-9da8-da1aca9b7fba', 'ec012370-6ffa-4a3a-b230-2c62613f1d89']
# USER              : imran.rashid
# STATUS            : Available
# TIME CREATED      : 2024-02-21T13:13:34.584168+00:00
#
#
# ASR_pipeline_test_dataset
# =========================
#
# PATH              : default/cap-engagements/datasets/local-dataset-c23b50b8-9cce-44ec-b339-f79d480659d0
# APPS              : ['b6aefdf7-02a4-4384-9c3c-8a81d735a54e']
# USER              : jorge.piedrahita
# STATUS            : Available
# TIME CREATED      : 2024-02-22T21:42:11.789384+00:00
#
#
# PCA_test
# ========
#
# PATH              : default/cap-engagements/datasets/local-dataset-42cf8587-6ce1-41bb-b7a4-2a069ae146bc
# APPS              : ['b6aefdf7-02a4-4384-9c3c-8a81d735a54e']
# USER              : rodrigo.maldonado
# STATUS            : Available
# TIME CREATED      : 2024-02-23T16:38:10.159939+00:00
#
#
# yoda_qamixed_7btokenized
# ========================
#
# PATH              : default/cap-engagements/datasets/local-dataset-fff15fb0-81a7-459e-9274-501dbea10c9c
# APPS              : ['ec012370-6ffa-4a3a-b230-2c62613f1d89', '82254d3b-7239-458b-9da8-da1aca9b7fba']
# USER              : imran.rashid
# STATUS            : Available
# TIME CREATED      : 2024-02-26T03:28:11.706272+00:00
#
#
# yoda_qamixed_70btokenized
# =========================
#
# PATH              : default/cap-engagements/datasets/local-dataset-fad6acb3-fa40-4a45-95de-c57c5ebf6c89
# APPS              : ['82254d3b-7239-458b-9da8-da1aca9b7fba', 'ec012370-6ffa-4a3a-b230-2c62613f1d89']
# USER              : imran.rashid
# STATUS            : Available
# TIME CREATED      : 2024-02-26T03:29:49.304900+00:00
#
#
# PostCallAnalysis_dataset
# ========================
#
# PATH              : default/cap-engagements/datasets/local-dataset-cd5bf32a-3a70-46fe-8c37-e9b9086d6bf8
# APPS              : ['b6aefdf7-02a4-4384-9c3c-8a81d735a54e']
# USER              : rodrigo.maldonado
# STATUS            : Available
# TIME CREATED      : 2024-02-27T18:49:51.329005+00:00
#
#
# PCA_dataset
# ===========
#
# PATH              : default/cap-engagements/datasets/local-dataset-d87e5314-0365-406b-a6c3-d233fda86065
# APPS              : ['b6aefdf7-02a4-4384-9c3c-8a81d735a54e']
# USER              : rodrigo.maldonado
# STATUS            : Available
# TIME CREATED      : 2024-02-27T19:12:40.960835+00:00

# %%
# !snapi dataset info --dataset PCA_dataset
# Out:
# Failed to get dataset

# %%
asr.search_dataset()
# Out:
# ERROR:root:GET request failed with status code: 500
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[161], line 1
# ----> 1 asr.search_dataset()
#
# Cell In[155], line 92, in BatchASRProcessor.search_dataset(self)
#      88 url = self.base_url + self.datasets_url + '/search'
#      89 params = {
#      90     'dataset_name': self.dataset_name
#      91 }
# ---> 92 response = self._get_call(url, params, f'Dataset {self.dataset_name} found in SambaStudio')
#      93 parsed_reponse = json.loads(response.text)
#      94 return parsed_reponse['data']['dataset_id']
#
# Cell In[155], line 45, in BatchASRProcessor._get_call(self, url, params, success_message)
#      43 else:
#      44     logging.error(f'GET request failed with status code: {response.status_code}')
# ---> 45     raise Exception(f'Error message: {response.text}')
#      46 return response
#
# Exception: Error message: {"detail":"Something went wrong"}

# %%
asr.delete_dataset()
# Out:
# INFO:root:GET request successful!
# INFO:root:Dataset PCA_dataset found in SambaStudio
# INFO:root:Dataset PCA_dataset deleted successfully.
# {"detail":"The Dataset: f335c6f9-dfdb-4f41-a5b8-00b9e0784abe was successfully marked for deletion from the Dataset Hub."}

# %%
# test time and if dataset creation is async or not
start = time.time()
asr.create_dataset(path='../test_data/911_test.wav')
end = time.time()
asr.check_dataset_creation_progress()
end2 = time.time()
print(start)
print(end)
print(end2)
# Out:
# Folder Information:
#   - Number of Files: 1
#   - Total Size: 19.62 MB
#
# Are you sure you want to proceed? (yes/no)
# : Uploading files
# INFO:root:Creating dataset: PCA_dataset
# Dataset folder upload complete: ../data/datasets/PCA_dataset
# Dataset added successfully.
# Time taken to upload the dataset: 3.572451114654541 seconds
# https://sjc1-demo1.sambanova.net/api/datasets/PCA_dataset
# ERROR:root:GET request failed with status code: 500
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[160], line 4
#       2 asr.create_dataset(path='../test_data/911_test.wav')
#       3 end = time.time()
# ----> 4 asr.check_dataset_creation_progress()
#       5 end2 = time.time()
#       6 print(start)
#
# Cell In[155], line 213, in BatchASRProcessor.check_dataset_creation_progress(self)
#     211 url = self.base_url + self.datasets_url + '/' + self.dataset_name
#     212 print(url)
# --> 213 response = self._get_call(url)
#     214 print(response.text)
#     215 # status = PENDING_RDU_JOB_STATUS
#     216 # while status != SUCCESS_JOB_STATUS:
#     217 #     response = self._get_call(url, success_message='Still waiting for job to finish')
#    (...)
#     223 #         break
#     224 #     time.sleep(10)
#
# Cell In[155], line 45, in BatchASRProcessor._get_call(self, url, params, success_message)
#      43 else:
#      44     logging.error(f'GET request failed with status code: {response.status_code}')
# ---> 45     raise Exception(f'Error message: {response.text}')
#      46 return response
#
# Exception: Error message: {"detail":"Failed to get dataset"}

# %%
project_id = asr.create_load_project()
# Out:
# INFO:root:GET request successful!
# INFO:root:Project PostCallAnalysis_Project found in SambaStudio

# %%
job_id = asr.run_job(project_id, dataset_name)
# Out:
# INFO:root:POST request successful!
# INFO:root:Job running

# %%
result = asr.check_job_progress(project_id, job_id)
# Out:
# INFO:root:GET request successful!
# INFO:root:Still waiting for job to finish
# INFO:root:Job status: PENDING_RDU
# INFO:root:GET request successful!
# INFO:root:Still waiting for job to finish
# INFO:root:Job status: PENDING_RDU
# INFO:root:GET request successful!
# INFO:root:Still waiting for job to finish
# INFO:root:Job status: PENDING_RDU
# INFO:root:GET request successful!
# INFO:root:Still waiting for job to finish
# INFO:root:Job status: PREDICTING
# INFO:root:GET request successful!
# INFO:root:Still waiting for job to finish
# INFO:root:Job status: PREDICTING
# INFO:root:GET request successful!
# INFO:root:Still waiting for job to finish
# INFO:root:Job status: PREDICTING
# INFO:root:GET request successful!
# INFO:root:Still waiting for job to finish
# INFO:root:Job status: PREDICTING
# INFO:root:GET request successful!
# INFO:root:Still waiting for job to finish
# INFO:root:Job status: PREDICTING
# INFO:root:GET request successful!
# INFO:root:Still waiting for job to finish
# INFO:root:Job status: PREDICTING
# INFO:root:GET request successful!
# INFO:root:Still waiting for job to finish
# INFO:root:Job status: PREDICTING
# INFO:root:GET request successful!
# INFO:root:Still waiting for job to finish
# INFO:root:Job status: PREDICTING
# INFO:root:GET request successful!
# INFO:root:Still waiting for job to finish
# INFO:root:Job status: EXIT_WITH_0
# INFO:root:Job finished!

# %%
df = asr.retrieve_results(project_id, job_id)
df
# Out:
# INFO:root:GET request successful!
# INFO:root:Results downloaded!
#     start_time  end_time     speaker  \
# 0            0       2.5  SPEAKER_01
# 1            3      11.9  SPEAKER_00
# 2           11      12.3  SPEAKER_01
# 3           13      14.7  SPEAKER_00
# 4           14      14.6  SPEAKER_01
# 5           15      16.6  SPEAKER_00
# 6           17      21.4  SPEAKER_01
# 7           22      31.6  SPEAKER_00
# 8           32      37.2  SPEAKER_01
# 9           38      39.5  SPEAKER_00
# 10          40      53.0  SPEAKER_01
# 11          56      58.0  SPEAKER_00
# 12          57      62.9  SPEAKER_01
# 13          63      71.9  SPEAKER_00
# 14          72      82.4  SPEAKER_01
# 15          84      87.3  SPEAKER_00
# 16          87      88.7  SPEAKER_01
# 17          89      96.7  SPEAKER_00
# 18          96     100.4  SPEAKER_01
# 19         101     105.5  SPEAKER_00
# 20         105     114.6  SPEAKER_01
#
#                                                  text
# 0           Our Primeti 33. What is yet as emergency?
# 1   Yes, sir, I need to, uh, uh. I need an ambulan...
# 2                                              A car.
# 3                              Carol Wood Drive. Yes.
# 4                                                 NaN
# 5                                            Yeah, I.
# 6   Okay, sir. What's the phone number you calling...
# 7   Uh, sir? Oh, I have a. We have a gentleman her...
# 8   Okay, how does he. He's a 50 years old. Ser 50...
# 9                       Yes, he's not breathing, sir.
# 10  Okay, and he's not conscious either. Don't con...
# 11      We need them. You get when you just party on.
# 12  Just you in a way there. We're on Wemo. But I ...
# 13  Yes, we have a personal doctor if you're with ...
# 14  Oh, okay, well, we're on our way there. If you...
# 15  Uh, no, just the doctor. So the doctor's been ...
# 16               Okay, so did doctor see what happen.
# 17  Uh, um, doctor, did you see what happens to an...
# 18  Okay, we're in a way. I'm just I'm just passin...
# 19  A you cure's pumping. He's pumping his chest, ...
# 20  Okay, okay, we're on it. We're less than a mil...
